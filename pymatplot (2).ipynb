# %%
# Import `pyplot`
import matplotlib.pyplot as plt

# Initialize a Figure 
fig = plt.figure()

# Add Axes to the Figure
fig.add_axes([0,0,1,1])
plt.show()

# %%
#Plotting to our canvas
plt.plot([1,2,3],[4,5,1])

#Showing what we plotted
plt.show()

# %%
x = [5,8,10]
y = [12,16,6]

plt.plot(x,y)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
import pandas as pd
# CSV File - Read
df = pd.read_csv('C:\\Users\\HP\\Downloads\cereals.csv')

df2 = df.head(10)

#fig, ax = plt.subplots()

# %%
plt.bar(df2['name'], df2['rating'], align='center',color='g')
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(df2['name'], df2['rating'], color='g')
plt.xticks(rotation=90)
plt.title('Cereals Name Vs Rating')
plt.ylabel('Rating')
plt.xlabel('Name')
plt.show()

# %%
plt.plot(df2['name'], df2['rating'])
plt.xticks(rotation=90)
plt.show()

# %%
# Save Figure
#plt.savefig("foo.png")

# Save Transparent Figure
#plt.savefig("foo.png", transparent=True)

# %%
plt.hist(df['rating'], bins=10, color='green')
plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, colors=colors,)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.show()

# %%
# Create a list of colors (from iWantHue)
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

#df.head()
#x = df.groupby([ 'mfr', 'calories']).mean()

x = df.groupby('mfr')['calories'].mean()
print(x)
# Out:
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     86.666667
# P    107.500000
# Q     95.000000
# R    103.333333
# Name: calories, dtype: float64

# %%
# Create a pie chart
plt.pie(
    # using data total)arrests
    x,
    # with the labels being officer names
    labels=x.index,
    # with no shadows
    shadow=False,
    # with colors
    colors=colors,
    # with one slide exploded out
    #explode=(0, 0, 0, 0, 0.15,0,0),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %%
from pandas.plotting import parallel_coordinates
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('C:\\Users\\HP\\Downloads\cereals.csv')

dfnew = df[['mfr','calories','protein','rating']]

 
plt.figure()


parallel_coordinates(dfnew, 'mfr')
plt.show()
