# %%
# Import `pyplot`
import matplotlib.pyplot as plt

# Initialize a Figure 
fig = plt.figure()

# Add Axes to the Figure
fig.add_axes([0,0,1,1])
#Plotting to our canvas
plt.plot([1,2,3],[4,5,1])

plt.title('Plot by XYZ')
plt.xlabel('Hour')
plt.ylabel('concentration in mg')

plt.show()

# %%
import pandas as pd
# CSV File - Read
df = pd.read_csv('C:\\Users\\HP\\Downloads\cereals.csv')

df2 = df.head(10)

# %%
df2.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4             Almond_Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
plt.bar(df2['mfr'], df2['rating'], align='center',color='g')
#plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(df2['name'], df2['rating'], color='g')
plt.xticks(rotation=90)
plt.title('Cereals Name Vs Rating')
plt.ylabel('Rating')
plt.xlabel('Name')

plt.savefig("c:/users/hp/downloads/cerealsA.jpg")
plt.show()

# %%
plt.hist(df['rating'], bins=10, color='green')
plt.show()

# %%
# Create a list of colors (from iWantHue)
colors = ["#E13F29", "#D69A80", "#D63B59", "#AE5552", "#CB5C3B", "#EB8076", "#96624E"]

#df.head()
#x = df.groupby([ 'mfr', 'calories']).mean()

x = df.groupby('mfr')['calories'].mean()
print(x)
# Out:
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     86.666667
# P    107.500000
# Q     95.000000
# R    103.333333
# Name: calories, dtype: float64

# %%
# Create a pie chart
plt.pie(
    # using data total)arrests
    x,
    # with the labels being officer names
    labels=x.index,
    # with no shadows
    shadow=True,
    # with colors
    colors=colors,
    # with one slide exploded out
    explode=(0, 0, 0, 0, 0.15,0,0),
    # with the start angle at 90%
    startangle=90,
    # with the percent listed as a fraction
    autopct='%1.1f%%',
    )

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %%
import plotly 

import plotly.plotly as py
plotly.tools.set_credentials_file(username='gpavankumar1974', api_key='ZC1Yj1MngDCYkQV3oEuA')

import plotly.graph_objs as go

trace0 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
data = [trace0, trace1]

py.iplot(data, filename = 'basic-line', auto_open=True)
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~gpavankumar1974/0 or inside your plot.ly account where it is named 'basic-line'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~gpavankumar1974/0.embed" height="525px" width="100%"></iframe>
