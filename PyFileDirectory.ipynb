# %%
f = open("sampleText.txt", "r")
print(f.read())
# Out:
# The government has detected GST evasion worth ?38,896 crore in 6,585 cases in the April-October period of 2018-19, Parliament was informed on Friday.
#
# Minister of State for Finance Shiv Pratap Shukla said while central excise evasion of ?3,028.58 crore in 398 cases was unearthed during the seven-month period, service tax evasion of ?26,108.43 crore was detected in 3,922 cases.
#
# Customs evasion was detected in 12,711 cases involving ?6,966.04 crore and Goods and Services Tax (GST) evasion worth ?38,895.97 crore was unearthed in 6,585 cases, he said in a written reply in the Lok Sabha.
#
# The total amount of evasion in indirect taxes (GST, service tax, excise and customs) during April-October adds up to about ?75,000 crore.

# %%
#"a" - Append - will append to the end of the file

#"w" - Write - will overwrite any existing content

f = open("demofile1.txt", "x")
f.write("Hai imarticus!")
f.close()

# %%
# File exists
import os
if os.path.exists("demofile.txt"):
  os.remove("demofile.txt")
else:
  print("The file does not exist")

# %%
# Import `os` 
import os
# Retrieve current working directory (`cwd`)
cwd = os.getcwd()
cwd
# List all files and directories in current directory
os.listdir('.')
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.spyder-py3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'dataset.py',
#  'dataset.py.ipynb',
#  'demofile1.txt',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'fruit_classifier.txt',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TM.blf',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'Pictures',
#  'PrintHood',
#  'PyCNN.ipynb',
#  'PyDecisionTree.ipynb',
#  'PyFileDirectory.ipynb',
#  'PyopencVideo.ipynb',
#  'PyOpenCVImage.ipynb',
#  'Pyopencvimage2.ipynb',
#  'pySVMBasic.ipynb',
# ...

# %%
# Read Excel file
# Import pandas
import pandas as pd

# Assign spreadsheet filename to `file`
file = 'train2Excel.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# Print the sheet names
print(xl.sheet_names)

# Load a sheet into a DataFrame by name: df1
df1 = xl.parse('train')
df1.head()
# Out:
# ['train']
#                 ID  Gender                  DOB   Lead_Creation_Date  \
# 0  APPC90493171225  Female             23/07/79             15/07/16
# 1  APPD40611263344    Male  1986-07-12 00:00:00  2016-04-07 00:00:00
# 2  APPE70289249423    Male  1982-10-12 00:00:00             19/07/16
# 3  APPF80273865537    Male             30/01/89  2016-09-07 00:00:00
# 4  APPG60994436641    Male             19/04/85             20/07/16
#
#   City_Code City_Category Employer_Code Employer_Category1  \
# 0    C10001             A    COM0044082                  A
# 1    C10003             A    COM0000002                  C
# 2    C10125             C    COM0005267                  C
# 3    C10477             C    COM0004143                  A
# 4    C10002             A    COM0001781                  A
#
#    Employer_Category2  Monthly_Income    ...    Contacted Source  \
# 0                 4.0          2000.0    ...            N   S122
# ...

# %%
import os

for root, dirs, files in os.walk("C:\\Users\\pavan\\Downloads\\dt"):  
    for filename in files:
        print(filename)
# Out:
# 00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552.png
# 07a9bf1d7594af2763c86e93f05d22c4d5181353c6d3ab30a345b908ffe5aadc.png
# 0e548d0af63ab451616f082eb56bde13eb71f73dfda92a03fbe88ad42ebb4881.png
# 0ea1f9e30124e4aef1407af239ff42fd6f5753c09b4c5cac5d08023c328d7f05.png
# 0f5a3252d05ecdf453bdd5e6ad5322c454d8ec2d13ef0f0bf45a6f6db45b5639.png
# 2c47735510ef91a11fde42b317829cee5fc04d05a797b90008803d7151951d58.png
# 4afa39f2a05f9884a5ff030d678c6142379f99a5baaf4f1ba7835a639cb50751.png
# 4bc58dbdefb2777392361d8b2d686b1cc14ca310e009b79763af46e853e6c6ac.png
# 4e3b49fb14877b63704881a923365b68c1def111c58f23c66daa49fef4b632bf.png
# 5522143fa8723b66b1e0b25331047e6ae6eeec664f7c8abeba687e0de0f9060a.png
# 58656859fb9c13741eda9bc753c3415b78d1135ee852a194944dee88ab70acf4.png
# 6442251746caac8fc255e6a22b41282ffcfabebadbd240ee0b604808ff9e3383.png
# 7ff04129f8b6d9aaf47e062eadce8b3fcff8b4a29ec5ad92bca926ac2b7263d2.png
# 8bbec3052bcec900455e8c7728d03facb46c880334bcc4fb0d1d066dd6c7c5d2.png
# ...

# %%
import os, fnmatch

listOfFiles = os.listdir('C:\\Users\\pavan\\Downloads\\')  
pattern = "*.pdf"  
for entry in listOfFiles:  
    if fnmatch.fnmatch(entry, pattern):
            print (entry)
# Out:
# ADR1.pdf
# ADR2.pdf
# ADR3.pdf
# CPC 2ND INTERNALS.pdf
# PGCLbasheerbaghworkshop.pdf
# v51i04.pdf
# Xe_CQ_Assessment_Nov_2018_v01.pdf

# %%
import os

def files(path):  
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file

for file in files("C:\\Users\\pavan\\Downloads\\IMG"):  
    print (file)
# Out:
# watch1.jpg
# watchgray2.png
# WhatsApp Image 2018-12-18 at 04.31.26 (3).jpeg
