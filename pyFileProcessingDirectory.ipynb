# %%
f = open("c:/users/hp/downloads/sampleText.txt", "r")
print(f.read())
# Out:
# The government has detected GST evasion worth ?38,896 crore in 6,585 cases in the April-October period of 2018-19, Parliament was informed on Friday.
#
# Minister of State for Finance Shiv Pratap Shukla said while central excise evasion of ?3,028.58 crore in 398 cases was unearthed during the seven-month period, service tax evasion of ?26,108.43 crore was detected in 3,922 cases.
#
# Customs evasion was detected in 12,711 cases involving ?6,966.04 crore and Goods and Services Tax (GST) evasion worth ?38,895.97 crore was unearthed in 6,585 cases, he said in a written reply in the Lok Sabha.
#
# The total amount of evasion in indirect taxes (GST, service tax, excise and customs) during April-October adds up to about ?75,000 crore.

# %%
f = open("c:/users/hp/downloads/demofile1.txt", "w")
f.write("Hai imarticus!")
f.close()

# %%
# File exists
import os
if os.path.exists("c:/users/hp/downloads/demofile1.txt"):
    f = open("c:/users/hp/downloads/demofile1.txt", "r")
    print(f.read())
    
    #os.remove("demofile.txt")

else:
  print("The file does not exist")
# Out:
# Hai imarticus!

# %%
# Import `os` 
import os
# Retrieve current working directory (`cwd`)
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\HP'

# %%
# List all files and directories in current directory
os.listdir('c:/users/hp/downloads/')
# Out:
# ['.Rhistory',
#  '08.Exercise.R',
#  '2.jpg',
#  '2511workDSP-10.pptx',
#  '39220316_1553968377074.xls',
#  '500_questions.csv',
#  '8. Code of Civil Procedure, 1908.pdf',
#  'ADR Record.pdf',
#  'adr.csv',
#  'adr.txt',
#  'Agreement For Sale.doc',
#  'Algorithms.pptx',
#  'all.zip',
#  'alpha_beta1.ipynb',
#  'Anaconda3-5.2.0-Windows-x86_64.exe',
#  'ANDHRA PRADESH BUILDINGS (LEASE, RENT AND EVICTION) CONTROL ACT, 1960.docx',
#  'anova.csv',
#  'Application Functional Analytics.pptx',
#  'ARL.ipynb',
#  'assign2bmi_dataframe.r',
#  'assignment1.py',
#  'Assumption of Linearity.pptx',
#  'attachments.zip',
#  'bank.csv',
#  'banking.csv',
#  'banking1.ipynb',
#  'BankingAssesment.ipynb',
#  'BankingAssesment_Linear.ipynb',
#  'Barley.data.csv',
#  'Barley.data.csv.zip',
#  'Bayesian network.pptx',
#  'Bayesian Neural.pptx',
#  'BMI Exercise.R',
#  'BMI-Work.txt',
#  'BMILevel1Py.ipynb',
#  'Bridge_Tableau (1).pdf',
#  'Bridge_Tableau.pdf',
#  'CaseStudyonCreditRisk.docx',
# ...

# %%
import os

for root, dirs, files in os.walk("C:\\Users\\hp\\Downloads\\nucleu"):  
    for filename in files:
        print(filename)
# Out:
# 0114f484a16c152baa2d82fdd43740880a762c93f436c8988ac461c5c9dbe7d5.png
# 0999dab07b11bc85fb8464fc36c947fbd8b5d6ec49817361cb780659ca805eac.png
# 0a849e0eb15faa8a6d7329c3dd66aabe9a294cccb52ed30a90c8ca99092ae732.png
# 0e132f71c8b4875c3c2dd7a22997468a3e842b46aa9bd47cf7b0e8b7d63f0925.png
# 0ed3555a4bd48046d3b63d8baf03a5aa97e523aa483aaa07459e7afa39fb96c6.png
# 0f1f896d9ae5a04752d3239c690402c022db4d72c0d2c087d73380896f72c466.png
# 1747f62148a919c8feb6d607faeebdf504b5e2ad42b6b1710b1189c37ebcdb2c.png
# 17b9bf4356db24967c4677b8376ac38f826de73a88b93a8d73a8b452e399cdff.png
# 1879f4f4f05e2bada0ffeb46c128b8df7a79b14c84f38c3e216a69653495153b.png
# 191b2b2205f2f5cc9da04702c5d422bc249faf8bca1107af792da63cccfba829.png
# 1962d0c5faf3e85cda80e0578e0cb7aca50826d781620e5c1c4cc586bc69f81a.png
# 1cdbfee1951356e7b0a215073828695fe1ead5f8b1add119b6645d2fdc8d844e.png
# 1d9eacb3161f1e2b45550389ecf7c535c7199c6b44b1c6a46303f7b965e508f1.png
# 1ef68e93964c2d9230100c1347c328f6385a7bc027879dc3d4c055e6fe80cb3c.png
# ...

# %%
import os, fnmatch

listOfFiles = os.listdir('C:\\Users\\hp\\Downloads\\')  
pattern = "*.pdf"  
for entry in listOfFiles:  
    if fnmatch.fnmatch(entry, pattern):
            print (entry)
# Out:
# 8. Code of Civil Procedure, 1908.pdf
# ADR Record.pdf
# Bridge_Tableau (1).pdf
# Bridge_Tableau.pdf
# cerealspga05.pdf
# commercial-property-rental-agreement-format.pdf
# court visit n civil case of prr.pdf
# credit card report (1).pdf
# credit card report.pdf
# Data_Scientist_Resume_Format1.pdf
# Decision-Tree.pdf
# Deed of Dissolution of Partnership.pdf
# Deeds_DPC_PartA.pdf
# DPC deeds full.pdf
# eftos-ent-kingdom-of-a-thousand (1).pdf
# eftos-ent-kingdom-of-a-thousand.pdf
# Feb 15 - Rental Agreement (1).pdf
# Feb 15 - Rental Agreement.pdf
# Feb 15 - Sale Deed.pdf
# HC_PIL_Rules_APTelangana_2015.pdf
# Income Tax Internals.pdf
# Information technology internal questions.pdf
# investments and securities (internals) o_20190323122614.pdf
# Jurisdiction of Courts-PS 2019- NEW.pdf
# Kankadhara.pdf
# LLB_S5_ADR_Negotiation_Problem1 (1).pdf
# LLB_S5_ADR_Negotiation_Problem1.pdf
# LLB_S5_ADR_Negotiation_Problem2.pdf
# LLB_S6_MootCourt_Problems (1).pdf
# LLB_S6_MootCourt_Problems.pdf
# ...

# %%
import os

def func(path):  
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file

for file in func("C:\\Users\\hp\\Downloads\\evaluation\\cat"):  
    print (file)
# Out:
# 10.jpg
# 100.jpg
# 101.jpg
# 103.jpg
# 104.jpg
# 107.jpg
# 108.jpg
# 11.jpg
# 114.jpg
# 115.jpg
# 116.jpg
# 117.jpg
# 120.jpg
# 121.jpg
# 122.jpg
# 123.jpg
# 124.jpg
# 125.jpg
# 128.jpg
# 129.jpg
# 13.jpg
# 133.jpg
# 134.jpg
# 135.jpg
# 136.jpg
# 139.jpg
# 14.jpg
# 140.jpg
# 141.jpg
# 144.jpg
# 145.jpg
# 148.jpg
# 149.jpg
# 15.jpg
# 150.jpg
# 152.jpg
# 153.jpg
# 154.jpg
# 156.jpg
# 157.jpg
# 16.jpg
# 161.jpg
# 162.jpg
# 163.jpg
# 165.jpg
# 166.jpg
# 168.jpg
# 169.jpg
# 170.jpg
# 171.jpg
# 174.jpg
# 180.jpg
# 183.jpg
# 184.jpg
# 185.jpg
# 187.jpg
# 188.jpg
# 19.jpg
# 20.jpg
# 22.jpg
# 25.jpg
# 28.jpg
# 29.jpg
# 34.jpg
# 35.jpg
# 36.jpg
# 37.jpg
# 38.jpg
# 40.jpg
# 45.jpg
# 47.jpg
# 5.jpg
# 50.jpg
# 51.jpg
# 52.jpg
# 53.jpg
# 54.jpg
# 55.jpg
# 58.jpg
# 6.jpg
# 60.jpg
# 61.jpg
# 63.jpg
# 64.jpg
# 68.jpg
# 7.jpg
# 75.jpg
# 8.jpg
# 80.jpg
# 81.jpg
# 82.jpg
# 84.jpg
# 89.jpg
# 9.jpg
# 90.jpg
# 91.jpg
# 92.jpg
# 93.jpg
# 96.jpg
# 99.jpg

# %%
# Read Excel file
# Import pandas
import pandas as pd

# Assign spreadsheet filename to `file`
file = 'C:\\Users\\hp\\Downloads\\train2Excel.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# Print the sheet names
print(xl.sheet_names)

# Load a sheet into a DataFrame by name: df1
df1 = xl.parse('train')
df1.head()
# Out:
# ['train']
#                 ID  Gender                  DOB   Lead_Creation_Date  \
# 0  APPC90493171225  Female             23/07/79             15/07/16
# 1  APPD40611263344    Male  1986-07-12 00:00:00  2016-04-07 00:00:00
# 2  APPE70289249423    Male  1982-10-12 00:00:00             19/07/16
# 3  APPF80273865537    Male             30/01/89  2016-09-07 00:00:00
# 4  APPG60994436641    Male             19/04/85             20/07/16
#
#   City_Code City_Category Employer_Code Employer_Category1  \
# 0    C10001             A    COM0044082                  A
# 1    C10003             A    COM0000002                  C
# 2    C10125             C    COM0005267                  C
# 3    C10477             C    COM0004143                  A
# 4    C10002             A    COM0001781                  A
#
#    Employer_Category2  Monthly_Income    ...    Contacted Source  \
# 0                 4.0          2000.0    ...            N   S122
# ...

# %%
import json
import pandas as pd

from pandas.io.json import json_normalize

data = {  
   "ISBN:0385472579":{  
      "bib_key":"ISBN:0385472579",
      "preview":"noview",
      "thumbnail_url":"https://covers.openlibrary.org/b/id/240726-S.jpg",
      "preview_url":"https://openlibrary.org/books/OL1397864M/Zen_speaks",
      "info_url":"https://openlibrary.org/books/OL1397864M/Zen_speaks"
   },
   "LCCN:62019420":{  
      "bib_key":"LCCN:62019420",
      "preview":"noview",
      "preview_url":"https://openlibrary.org/books/OL5857365M/The_adventures_of_Tom_Sawyer",
      "info_url":"https://openlibrary.org/books/OL5857365M/The_adventures_of_Tom_Sawyer"
   }
}
  

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')

print(df)
# Out:
#   ISBN:0385472579.bib_key                           ISBN:0385472579.info_url  \
# 0         ISBN:0385472579  https://openlibrary.org/books/OL1397864M/Zen_s...
#
#   ISBN:0385472579.preview                        ISBN:0385472579.preview_url  \
# 0                  noview  https://openlibrary.org/books/OL1397864M/Zen_s...
#
#                       ISBN:0385472579.thumbnail_url LCCN:62019420.bib_key  \
# 0  https://covers.openlibrary.org/b/id/240726-S.jpg         LCCN:62019420
#
#                               LCCN:62019420.info_url LCCN:62019420.preview  \
# 0  https://openlibrary.org/books/OL5857365M/The_a...                noview
#
#                            LCCN:62019420.preview_url
# 0  https://openlibrary.org/books/OL5857365M/The_a...

# %%
import json
import pandas as pd

from pandas.io.json import json_normalize

data = [
    {
      "color": "black",
      "category": "hue",
      "type": "primary",
      "code": {
        "rgba": [255,255,255,1],
        "hex": "#000"
      }
    },
    {
      "color": "white",
      "category": "value",
      "code": {
        "rgba": [0,0,0,1],
        "hex": "#FFF"
      }
    },
    {
      "color": "red",
      "category": "hue",
      "type": "primary",
      "code": {
        "rgba": [255,0,0,1],
        "hex": "#FF0"
      }
    },
    {
      "color": "blue",
      "category": "hue",
      "type": "primary",
      "code": {
        "rgba": [0,0,255,1],
        "hex": "#00F"
      }
    },
    {
      "color": "yellow",
      "category": "hue",
      "type": "primary",
      "code": {
        "rgba": [255,255,0,1],
        "hex": "#FF0"
      }
    },
    {
      "color": "green",
      "category": "hue",
      "type": "secondary",
      "code": {
        "rgba": [0,255,0,1],
        "hex": "#0F0"
      }
    },
  ]

df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')

print(df)
# Out:
#   category code.hex           code.rgba   color       type
# 0      hue     #000  [255, 255, 255, 1]   black    primary
# 1    value     #FFF        [0, 0, 0, 1]   white        NaN
# 2      hue     #FF0      [255, 0, 0, 1]     red    primary
# 3      hue     #00F      [0, 0, 255, 1]    blue    primary
# 4      hue     #FF0    [255, 255, 0, 1]  yellow    primary
# 5      hue     #0F0      [0, 255, 0, 1]   green  secondary
