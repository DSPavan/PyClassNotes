# %%
# conda install -c conda-forge wordcloud
# pip install wordcloud

# %%
import nltk

from nltk.tokenize import sent_tokenize, word_tokenize

EXAMPLE_TEXT = "Sources in Chennai confirmed that the subject would be the handling of the Assembly polls in the State in 2021. Earlier last week, West Bengal Chief Minister Mamata Banerjee had also met with the IPAC founder and Janata Dal (U) vice president. Incidentally, the IPAC has also handled some aspects of film personality Kamal Haasan’s political campaign under the aegis of his party, Makkal Needhi Maiam (MNM)."


#print(sent_tokenize(EXAMPLE_TEXT))

L1 = sent_tokenize(EXAMPLE_TEXT)
for x in  L1:
    print(x,"\n")
# Out:
# Sources in Chennai confirmed that the subject would be the handling of the Assembly polls in the State in 2021.
#
# Earlier last week, West Bengal Chief Minister Mamata Banerjee had also met with the IPAC founder and Janata Dal (U) vice president.
#
# Incidentally, the IPAC has also handled some aspects of film personality Kamal Haasan’s political campaign under the aegis of his party, Makkal Needhi Maiam (MNM).

# %%
# .tokenize
# sent, word
print(word_tokenize(EXAMPLE_TEXT))
# Out:
# ['Sources', 'in', 'Chennai', 'confirmed', 'that', 'the', 'subject', 'would', 'be', 'the', 'handling', 'of', 'the', 'Assembly', 'polls', 'in', 'the', 'State', 'in', '2021', '.', 'Earlier', 'last', 'week', ',', 'West', 'Bengal', 'Chief', 'Minister', 'Mamata', 'Banerjee', 'had', 'also', 'met', 'with', 'the', 'IPAC', 'founder', 'and', 'Janata', 'Dal', '(', 'U', ')', 'vice', 'president', '.', 'Incidentally', ',', 'the', 'IPAC', 'has', 'also', 'handled', 'some', 'aspects', 'of', 'film', 'personality', 'Kamal', 'Haasan', '’', 's', 'political', 'campaign', 'under', 'the', 'aegis', 'of', 'his', 'party', ',', 'Makkal', 'Needhi', 'Maiam', '(', 'MNM', ')', '.']

# %%
#L1 = word_tokenize(EXAMPLE_TEXT)
#for x in  L1:
#    print(x,"\t")

# %%
from nltk.corpus import stopwords
example_sent = EXAMPLE_TEXT

stop_words = set(stopwords.words('english'))
#print(stop_words)

# %%
word_tokens = word_tokenize(example_sent)

#filtered_sentence = [w for w in word_tokens if not w in stop_words]

filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

#print(word_tokens)
print(filtered_sentence)
# Out:
# ['Sources', 'Chennai', 'confirmed', 'subject', 'would', 'handling', 'Assembly', 'polls', 'State', '2021', '.', 'Earlier', 'last', 'week', ',', 'West', 'Bengal', 'Chief', 'Minister', 'Mamata', 'Banerjee', 'also', 'met', 'IPAC', 'founder', 'Janata', 'Dal', '(', 'U', ')', 'vice', 'president', '.', 'Incidentally', ',', 'IPAC', 'also', 'handled', 'aspects', 'film', 'personality', 'Kamal', 'Haasan', '’', 'political', 'campaign', 'aegis', 'party', ',', 'Makkal', 'Needhi', 'Maiam', '(', 'MNM', ')', '.']

# %%
# Remove words
from nltk.text import Text

stop_words = nltk.corpus.stopwords.words('english')
newStopWords = [',', '.', "?","also","handled","aspects", '(', 'MNM', ')', 'U', '’', '2021'] # Remove words
stop_words.extend(newStopWords)

# %%
filtered_sentence2 = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence2.append(w)

#print(word_tokens)
print(filtered_sentence2)
# Out:
# ['Sources', 'Chennai', 'confirmed', 'subject', 'would', 'handling', 'Assembly', 'polls', 'State', 'Earlier', 'last', 'week', 'West', 'Bengal', 'Chief', 'Minister', 'Mamata', 'Banerjee', 'met', 'IPAC', 'founder', 'Janata', 'Dal', 'vice', 'president', 'Incidentally', 'IPAC', 'film', 'personality', 'Kamal', 'Haasan', 'political', 'campaign', 'aegis', 'party', 'Makkal', 'Needhi', 'Maiam']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
#example_words = ["python","pythoner","pythoning","pythoned","pythonly"]


for w in filtered_sentence2:
    print(ps.stem(w))
    
# stem(word)
# Out:
# sourc
# chennai
# confirm
# subject
# would
# handl
# assembl
# poll
# state
# earlier
# last
# week
# west
# bengal
# chief
# minist
# mamata
# banerje
# met
# ipac
# founder
# janata
# dal
# vice
# presid
# incident
# ipac
# film
# person
# kamal
# haasan
# polit
# campaign
# aegi
# parti
# makkal
# needhi
# maiam

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()


for word in filtered_sentence2:
    print(lemmatizer.lemmatize(word))
# Out:
# Sources
# Chennai
# confirmed
# subject
# would
# handling
# Assembly
# poll
# State
# Earlier
# last
# week
# West
# Bengal
# Chief
# Minister
# Mamata
# Banerjee
# met
# IPAC
# founder
# Janata
# Dal
# vice
# president
# Incidentally
# IPAC
# film
# personality
# Kamal
# Haasan
# political
# campaign
# aegis
# party
# Makkal
# Needhi
# Maiam

# %%
fdist = nltk.FreqDist(filtered_sentence2)
fdist

# Top 10 words
# High Frequency words
# Out:
# FreqDist({'IPAC': 2, 'Sources': 1, 'Chennai': 1, 'confirmed': 1, 'subject': 1, 'would': 1, 'handling': 1, 'Assembly': 1, 'polls': 1, 'State': 1, ...})

# %%
from nltk.text import Text
aText = Text(nltk.corpus.gutenberg.words('E:\\sage\\sampleText.txt'))
fdist = nltk.FreqDist(aText)
fdist
# Out:
# FreqDist({',': 15, 'in': 9, '.': 8, 'evasion': 6, '?': 6, 'crore': 6, 'cases': 5, 'of': 5, 'was': 5, '-': 4, ...})

# %%
print(len(fdist))
# Out:
# 86

# %%
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = [',', 'in', '.', '?','26', '108', '43', '922',]
stopwords.extend(newStopWords)

##
filtered_sentence2 = []

for w in fdist:
    if w not in stop_words:
        filtered_sentence2.append(w)

#print(word_tokens)
print(filtered_sentence2)
# freqdistPlot
# Out:
# ['The', 'government', 'detected', 'GST', 'evasion', 'worth', '38', '896', 'crore', '6', '585', 'cases', 'April', '-', 'October', 'period', '2018', '19', 'Parliament', 'informed', 'Friday', 'Minister', 'State', 'Finance', 'Shiv', 'Pratap', 'Shukla', 'said', 'central', 'excise', '3', '028', '58', '398', 'unearthed', 'seven', 'month', 'service', 'tax', '26', '108', '43', '922', 'Customs', '12', '711', 'involving', '966', '04', 'Goods', 'Services', 'Tax', '895', '97', 'written', 'reply', 'Lok', 'Sabha', 'total', 'amount', 'indirect', 'taxes', 'customs', 'adds', '75', '000']

# %%
fdist = nltk.FreqDist(filtered_sentence2)
fdist
# Out:
# FreqDist({'The': 1, 'government': 1, 'detected': 1, 'GST': 1, 'evasion': 1, 'worth': 1, '38': 1, '896': 1, 'crore': 1, '6': 1, ...})

# %%
from nltk.text import Text
aText = Text(nltk.corpus.gutenberg.words('E:\\sage\\sampleText.txt'))
fdist = nltk.FreqDist(aText)
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['has', ".","?",",","The"]
stopwords.extend(newStopWords)
import matplotlib.pyplot as plt
# freqdistPlot
#fdist.plot(50, cumulative=True)
fdist_no_punc_no_stopwords = nltk.FreqDist(dict((word, freq) for word, freq in fdist.items() if word not in stopwords and word.isalpha()))
fdist_no_punc_no_stopwords.plot(10, cumulative=False, title="50 most common tokens (no stopwords or punctuation)")

# %%
# Find Top 10 Key words
# More than 3 Frequecy - count

# %%
from nltk.text import Text
aText = Text(nltk.corpus.gutenberg.words('E:\\sage\\sampleText.txt'))
fdist = nltk.FreqDist(aText)
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['has', ".","?",",","The","content"]
stopwords.extend(newStopWords)
import matplotlib.pyplot as plt
# freqdistPlot
#fdist.plot(50, cumulative=True)
fdist_no_punc_no_stopwords = nltk.FreqDist(dict((word, freq) for word, freq in fdist.items() if word not in stopwords and word.isalpha()))
fdist_no_punc_no_stopwords.plot(10, cumulative=False, title="50 most common tokens (no stopwords or punctuation)")
# # As a a Kay Tags of the Artcicle

# %%
# String Conversion - Lower, Upper, Title
# If the frequent words don't help us, how about the words that occur once only, the so-called hapaxes? 
#View them by typing fdist1.hapaxes(). This list contains lexicographer, cetological, contraband, expostulations,
# and about 9,000 others. It seems that there are too many rare words, and without seeing the context
#we probably can't guess what half of the hapaxes mean in any case! 
#Since neither frequent nor infrequent words help, we need to try something else.

# %%
print(fdist)
print(fdist.hapaxes())
# Low Freq words, But High impact
# As a a Kay Tags of the Artcicle
# Out:
# <FreqDist with 164 samples and 331 outcomes>
# ...

# %%
# A collocation is a pair or group of words that are habitually juxtaposed. For instance “red wine”
print(aText.collocations())
print(aText)
# Out:
# brain tissue; spectrum disorder; aluminium content; fluorescence
# microscopy; neuronal cells; autism spectrum; identify aluminium
# None
# <Text: Autism spectrum disorder is a neurodevelopmental disorder of...>

# %%
# word cloud
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
f = open("E:\\sage\\sampleText.txt","r")
#print(f.read())
textContent = f.read()
f.close()

# Open, Read/write , close

wordcloud = WordCloud().generate(textContent)

def plot_wordcloud(wordcloud):
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
plot_wordcloud(wordcloud)

# %%
import numpy as np
from PIL import Image
from os import path

img = Image.open("c:\\users\\hp\\downloads\\watchgray.png")
mask = np.array(img)


from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(relative_scaling=1.0, stopwords=stopwords, max_words=1000, mask=mask).generate(textContent)
#plot_wordcloud(wordcloud)

# %%
plot_wordcloud(wordcloud)

# %%
# # Part of Speech - From our Text
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer


custom_sent_tokenizer = PunktSentenceTokenizer(textContent)

tokenized = custom_sent_tokenizer.tokenize(textContent)

#print(tokenized)


def process_content():
    try:
        for i in tokenized[:5]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()

# python NLP pos tag list
# Out:
# [('Autism', 'NNP'), ('spectrum', 'NN'), ('disorder', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('neurodevelopmental', 'JJ'), ('disorder', 'NN'), ('of', 'IN'), ('unknown', 'JJ'), ('aetiology', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('is', 'VBZ'), ('suggested', 'VBN'), ('to', 'TO'), ('involve', 'VB'), ('both', 'DT'), ('genetic', 'JJ'), ('susceptibility', 'NN'), ('and', 'CC'), ('environmental', 'JJ'), ('factors', 'NNS'), ('including', 'VBG'), ('in', 'IN'), ('the', 'DT'), ('latter', 'JJ'), ('environmental', 'JJ'), ('toxins', 'NNS'), ('.', '.')]
# [('Human', 'JJ'), ('exposure', 'NN'), ('to', 'TO'), ('the', 'DT'), ('environmental', 'JJ'), ('toxin', 'NN'), ('aluminium', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('linked', 'VBN'), (',', ','), ('if', 'IN'), ('tentatively', 'RB'), (',', ','), ('to', 'TO'), ('autism', 'VB'), ('spectrum', 'JJ'), ('disorder', 'NN'), ('.', '.')]
# ...

# %%
# Part of Speech - Standard Example
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")
#print(train_text)

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

tokenized = custom_sent_tokenizer.tokenize(sample_text)

def process_content():
    try:
        for i in tokenized[:5]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()
# Out:
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W.', 'NNP'), ('BUSH', 'NNP'), ("'S", 'POS'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('January', 'NNP'), ('31', 'CD'), (',', ','), ('2006', 'CD'), ('THE', 'NNP'), ('PRESIDENT', 'NNP'), (':', ':'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('.', '.')]
# ...
