# %%
# pip install beautifulsoup4

# %%
import requests

page = requests.get("https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece?homepage=true")
page
# Out:
# <Response [200]>

# %%
#page.content
# commnented to minimize display !!

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#soup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    India to have a separate space station: ISRO - The Hindu
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="India to have a separate space station: ISRO" name="title">
#    <meta content="articlepage" name="atdlayout">
#     <meta content="The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission." name="description">
#      <meta content="!" name="fragment"/>
#      <meta content="gaganyaan,gaganyaan mission,gaganyaan programme,ISRO,Indian Space Research Organisation,international space station,India space spation,indian space station" name="keywords">
#       <meta content="gaganyaan,gaganyaan mission,gaganyaan programme,ISRO,Indian Space Research Organisation,international space station,India space spation,indian space station" name="news_keywords"/>
#       <meta content="2019-06-13T16:29:54+05:30" name="publish-date"/>
#       <meta content="2019-06-13T16:29:54+05:30" name="created-date"/>
#       <meta content="2019-06-13T17:41:40+05:30" name="modified-date"/>
#       <meta content="Dinakar Peri" name="twitter:creator"/>
#       <meta content="India to have a separate space station: ISRO" name="twitter:title"/>
#       <meta content="The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission." name="twitter:description"/>
#       <meta content="https://www.thehindu.com/sci-tech/science/vkf7rv/article26423945.ece/ALTERNATES/LANDSCAPE_615/SPACE-NASA" name="twitter:image"/>
#       <meta content="summary_large_image" name="twitter:card">
#        <meta content="@The_Hindu" name="twitter:site">
#         <meta content="thehindu.com" name="twitter:domain">
#          <meta content="The Hindu" name="twitter:app:name:ipad">
#           <meta content="The Hindu (Official App)" name="twitter:app:name:googleplay"/>
#           <meta content="com.mobstac.thehindu" name="twitter:app:id:googleplay"/>
#           <meta content="The Hindu for iPhone" name="twitter:app:name:iphone"/>
#           <meta content="771672321" name="twitter:app:id:iphone"/>
#           <meta content="app-id=584786636" name="apple-itunes-app"/>
#           <meta content="app-id=com.mobstac.thehindu" name="google-play-app"/>
#           <meta content="137450626398044" property="fb:app_id"/>
#           <meta content="163974433696568" property="fb:pages"/>
#           <meta content="The Hindu" property="og:site_name"/>
#           <meta content="https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece" property="og:url"/>
#           <meta content="article" property="og:type"/>
#           <meta content="India to have a separate space station: ISRO" property="og:title"/>
#           <meta content="The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission." property="og:description"/>
#           <meta content="https://www.thehindu.com/sci-tech/science/vkf7rv/article26423945.ece/ALTERNATES/LANDSCAPE_615/SPACE-NASA" property="og:image"/>
#           <meta content="image/jpeg" property="og:image:type"/>
#           <meta content="Dinakar Peri" property="article:author"/>
#           <meta content="gaganyaan" property="article:tag"/>
#           <meta content="gaganyaan mission" property="article:tag"/>
#           <meta content="gaganyaan programme" property="article:tag"/>
#           <meta content="ISRO" property="article:tag"/>
#           <meta content="Indian Space Research Organisation" property="article:tag"/>
#           <meta content="international space station" property="article:tag"/>
#           <meta content="India space spation" property="article:tag"/>
#           <meta content="indian space station" property="article:tag"/>
#           <meta content="Science" property="article:section"/>
#           <script type="application/ld+json">
#            {
# "@context": "https://schema.org",
# "@type": "NewsArticle",
# "mainEntityOfPage": {
# "@type": "WebPage",
# "@id": "https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece"
# },
# "headline": "India to have a separate space station: ISRO",
# "description": "The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission.",
# "keywords":"gaganyaan,gaganyaan mission,gaganyaan programme,ISRO,Indian Space Research Organisation,international space station,India space spation,indian space station",
# "datePublished": "2019-06-13T16:29:54+05:30",
# "dateModified": "2019-06-13T17:41:40+05:30",
# "author": {
# "@type": "Person",
# "name": "Dinakar Peri"
# },
# "image":{
# "@context": "https://schema.org",
# "@type": "ImageObject",
# "width": "300",
# "height": "187",
# "url":"https://www.thehindu.com/sci-tech/science/vkf7rv/article26423945.ece/ALTERNATES/LANDSCAPE_300/SPACE-NASA"
# },
# "publisher":{
# "@context": "https://schema.org",
# "@type": "Organization",
# "name": "The Hindu",
# "logo": {
# "@context": "https://schema.org",
# "@type": "ImageObject",
# "width": "600",
# "height": "60",
# "url": "https://www.thehindu.com/static/theme/default/base/img/thfooterlogo.png"
# },
# "url":"https://www.thehindu.com/"
# }
# }
#           </script>
#           <script type="application/ld+json">
#            {
# "@context": "https://schema.org",
# "@type": "Organization",
# "name": "The Hindu",
# "url": "https://www.thehindu.com/",
# "logo":"https://www.thehindu.com/static/theme/default/base/img/thfooterlogo.png",
# "address": {
# "@type": "PostalAddress",
# "streetAddress": "Kasturi Building, Anna Salai, 859-860, Mount Road",
# "addressLocality": "Chennai",
# "addressRegion": "Tamil Nadu",
# "postalCode": "600002",
# "Telephone": "+91-44-2857 6300"
# },
# "sameAs": [
# "https://www.facebook.com/thehindu",
# "https://twitter.com/The_Hindu",
# "https://instagram.com/the_hindu/?ref=badge",
# "https://www.youtube.com/user/The1878Hindu"
# ]
# }
#           </script>
#           <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#           <link href="//www.googletagservices.com" rel="preconnect"/>
#           <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#           <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
#           <link href="//pubads.g.doubleclick.net" rel="dns-prefetch"/>
#           <link href="//pubads.g.doubleclick.net" rel="preconnect"/>
#           <link href="//sb.scorecardresearch.com" rel="dns-prefetch"/>
#           <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#           <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#           <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#           <link as="script" href="https://www.googletagservices.com/tag/js/gpt.js" rel="prefetch"/>
#           <link href="https://www.thehindu.com/thfavicon.ico" rel="shortcut icon" type="image/x-icon">
#            <link href="https://www.thehindu.com/thfavicon.ico" rel="icon" type="image/ico">
#             <link href="https://www.thehindu.com/thapple-touch-icon.png" rel="apple-touch-icon">
#              <link href="https://www.thehindu.com/thapple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed">
#               <link href="https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece/amp/" rel="amphtml"/>
#               <link href="https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece" rel="canonical">
#                <link href="https://www.thehindu.com/manifest.json" rel="manifest"/>
#                <link href="https://fonts.googleapis.com/css?family=Fira+Sans:400,600" rel="stylesheet"/>
#                <link href="https://th.thgim.com/static/theme/default/base/css/default-base.bf81c2a06565c64978e16657a391fe72.min.css" rel="stylesheet"/>
#                <script>
#                 (function (w, d, u) {
# w.readyQ = [];
# w.bindReadyQ = [];
# function p(x, y) {
# if (x == "ready") {
# w.bindReadyQ.push(y);
# } else {
# w.readyQ.push(x);
# }
# };
# var a = {ready: p, bind: p};
# w.$ = w.jQuery = function (f) {
# if (f === d || f === u) {
# return a
# } else {
# p(f)
# }
# }
# })(window, document)
#                </script>
#                <script type="text/javascript">
#                 /* Front end properties configured in nursery */
# var FrontEndConfig = {"audioPlayer":"mediaelement","media.jwplayer.options.primary":"flash","media.jwplayer.ga.enabled":"true","media.jwplayer.hls.mimeTypes":"vnd.apple.mpegURL,application/x-mpegURL","videoPlayer":"flowplayer","media.jwplayer.sharing.enabled":"true","media.jwplayer.hls.enabled":"true"};
# if (typeof(FrontEndConfig) == 'undefined') {
# FrontEndConfig = {};
# }
# FrontEndConfig.rootURL = "https://www.thehindu.com/";
# /* Client-side device detection */
# var WFClientTypeDef = {"xlarge":"(min-width: 1600px)","large":"(min-width: 1024px) and (max-width: 1599px)","small":"(max-width: 767px)","medium":"(min-width: 768px) and (max-width: 1023px)"};
# var imageSizes = [80, 100, 115, 155, 170, 215, 230, 240, 300, 320, 355, 435, 460, 480, 615, 660, 730, 810, 960, 1080, 1140, 1200];
# var isMobile=false;
# var isTablet=false;
# var isDesktop=false;
# var isLargeDesktop=false;
# var DevIdf = {
# isMobile: false,
# isTablet: false,
# isDesktop: false,
# isLargeDesktop:false
# };
# var SubscribedUserPlan = {
# freetrail: false,
# purchased: false
# };
# for ( var type in WFClientTypeDef) {
# if (window.matchMedia(WFClientTypeDef[type]).matches) {
# switch (type) {
# case "xlarge":
# isLargeDesktop=true; DevIdf.isLargeDesktop=true;
# break;
# case "large":
# isDesktop=true;
# DevIdf.isDesktop=true;
# break;
# case "medium":
# isTablet=true; DevIdf.isTablet=true;	break;
# case "small":
# isMobile=true;
# DevIdf.isMobile=true;
# break;
# }
# break;
# }
# }
# $(function(){
# $.each(FrontEndConfig, function(key, value) {
# /* Regular properties other than JW Player setup options
# are being processed here */
# if (key.indexOf('media.jwplayer.options') < 0) {
# FrontEndConfig[key] = WFUtils.parseStringToJSONObject(value);
# }
# });
# });
# var isUser = true;
# var UserStatus = "anonymous";
# function isNonSubcribedUser(){
# return isUser;
# }
# function UserCurrentStatus(){
# if(isUserDetails != "" && !isNonSubcribedUser()){
# UserStatus = "paid";
# }
# else if (isUserDetails != "" && isNonSubcribedUser()){
# UserStatus = "registered";
# }
# return UserStatus;
# }
# function readCookie(name) {
# var nameEQ = name + "=";
# var ca = document.cookie.split(';');
# for(var i=0;i < ca.length;i++) {
# var c = ca[i];
# while (c.charAt(0)==' ') c = c.substring(1,c.length);
# if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# }
# return null;
# }
# function deleteCookie(name) {
# createCookiewithdomain(name,null,-1);
# }
# function createCookiewithdomain(name,value,days) {
# if (days) {
# var date = new Date();
# date.setTime(date.getTime()+(days*24*60*60*1000));
# var expires = "; expires="+date.toGMTString();
# }
# else var expires = "";
# document.cookie = name+"="+value+expires+"; domain="+document.location.host.match(/\.[.\w]*/)+";path=/";
# }
# function getUrlParameter( name, url ) {
# if (!url) url = location.href;
# name = name.replace(/[\[]/,"\\\[").replace(/[\]]/,"\\\]");
# var regexS = "[\\?&]"+name+"=([^&#]*)";
# var regex = new RegExp(regexS,"i");
# var results = regex.exec( url );
# return results == null ? null : results[1];
# }
# function getHostName(){
# return window.location.hostname;
# } function loadAsyncURL(url){ var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# s.type = "text/javascript";
# s.async = true; s.src = url; el.parentNode.insertBefore(s, el);
# }
# function loadSyncURL(url){ var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# s.type = "text/javascript";
# s.src = url; el.parentNode.insertBefore(s, el);
# }
# var isUserDetails = "";
# var deviceId = guidId();
# var siteId = "TRC-J3AFTO";
# var userId = "";
# function guidId() {
# var nav = window.navigator;
# var screen = window.screen;
# // var guid = nav.mimeTypes.length;
# var guid = nav.userAgent.replace(/\D+/g, '');
# // guid += nav.plugins.length;
# guid += screen.height || '';
# guid += screen.width || '';
# guid += screen.pixelDepth || '';
# document.cookie = "browserDeviceId="+guid;
# return guid;
# };
# if (!String.prototype.includes) {
# String.prototype.includes = function(search, start) {
# if (typeof start !== 'number') {
# start = 0;
# }
# if (start + search.length > this.length) {
# return false;
# } else {
# return this.indexOf(search, start) !== -1;
# }
# };
# }
# function taiApi(url){	var params = {"deviceId":deviceId, "siteId":siteId};
# if(url.includes("logout")){ params = {"userId":userId,"deviceId":deviceId, "siteId":siteId};}
# if (window.XMLHttpRequest)
# {
# // code for IE7+, Firefox, Chrome, Opera, Safari
# xhr =new XMLHttpRequest();
# }
# else
# {
# // code for IE6, IE5
# xhr =new ActiveXObject("Microsoft.XMLHTTP");
# }
# xhr.open('POST', url, false);
# xhr.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
# xhr.setRequestHeader('Content-type', 'application/json; charset=utf-8');
# xhr.withCredentials = true;
# xhr.crossDomain = true;
# xhr.onreadystatechange = function()
# {
# var status = xhr.status;
# if (xhr.readyState == 4 && xhr.status == 200)
# {
# var res = JSON.parse(xhr.response); if(res.status == "success" && url.includes("userInfo")){
# userId = res.userId;	if (userId != "") {
# isUserDetails = res; if(res.userPlanList.length > 0){
# for(var i =0; i < res.userPlanList.length ; i++){
# if(res.userPlanList[i].status == "success" && res.userPlanList[i].isActive == "1"){
# isUser = false;
# return false;
# }
# }
# }
# }
# else{
# eraseCookie("thuser");
# }
# }else if(url.includes("logout")){
# eraseCookie("thuser")
# window.location.reload();
# }
# }	};
# xhr.send(JSON.stringify(params));
# }
# if(readCookie("thuser")){
# taiApi("https://tai.thehindu.com/taiauth/userInfo/HINDU");	}
# var advtFillerFallback = "";
# var ReccoFillerFallback = "";
# function crossdomainXHR(curl,callbackfn){
# var url =curl;
# if (window.XMLHttpRequest)
# {
# // code for IE7+, Firefox, Chrome, Opera, Safari
# xhr =new XMLHttpRequest();
# }
# else
# {
# // code for IE6, IE5
# xhr =new ActiveXObject("Microsoft.XMLHTTP");
# }
# xhr.open('GET', url, false);
# xhr.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
# xhr.setRequestHeader('Content-type', 'application/json; charset=utf-8');
# xhr.withCredentials = true;
# xhr.crossDomain = true;
# xhr.onreadystatechange = function()
# {
# var status = xhr.status;
# if (xhr.readyState == 4 && xhr.status == 200)
# {
# callbackfn(xhr.response); }	};
# xhr.send();
# }
#                </script>
#                <script type="text/javascript">
#                 (function() {
# /** CONFIGURATION START **/
# var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
# _sf_async_config.uid = 65925;
# _sf_async_config.domain = 'www.thehindu.com'; //CHANGE THIS TO THE ROOT DOMAIN
# _sf_async_config.flickerControl = false;
# _sf_async_config.useCanonical = true;
# _sf_async_config.useCanonicalDomain = true;
# _sf_async_config.sections = 'Science'; // CHANGE THIS TO YOUR SECTION NAME(s)
# _sf_async_config.authors = 'Dinakar Peri'; // CHANGE THIS TO YOUR AUTHOR NAME(s)
# var _cbq = window._cbq = (window._cbq || []);
# if(UserCurrentStatus() == "paid"){
# _cbq.push(['_acct', 'paid']);	}
# else if (UserCurrentStatus() == "registered") {
# _cbq.push(['_acct', 'lgdin']);	}
# else {
# _cbq.push(['_acct', 'anon']);	}
# /** CONFIGURATION END **/
# function loadChartbeat() {
# var e = document.createElement('script');
# var n = document.getElementsByTagName('script')[0];
# e.type = 'text/javascript';
# e.async = true;
# e.src = '//static.chartbeat.com/js/chartbeat.js';;
# n.parentNode.insertBefore(e, n);
# }
# loadChartbeat();
# })();
#                </script>
#                <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js">
#                </script>
#                <!--[if lt IE 9]>
# <script src="https://th.thgim.com/static/js/html5shiv.js"></script>
# <script src="https://th.thgim.com/static/js/respond.min.js"></script>
# <![endif]-->
#                <script type="text/javascript">
#                 (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-10158580-1', 'auto');
# ga('send', 'pageview');
#                </script>
#                <script type="text/javascript">
#                 var _comscore = _comscore || []; _comscore.push({ c1: "2", c2: "11398210" }); (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#                </script>
#                <noscript>
#                 <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=123456&amp;cv=2.0&amp;cj=1"/>
#                </noscript>
#                <script type="text/javascript">
#                 function isDeviceEnabled(skipOnDeviceValue){	if(skipOnDeviceValue.indexOf("large") > -1 && (DevIdf.isDesktop || DevIdf.isLargeDesktop)){return false;}	if(skipOnDeviceValue.indexOf("medium") > -1 && DevIdf.isTablet){return false;}	if(skipOnDeviceValue.indexOf("small") > -1 && DevIdf.isMobile){return false;}	return true;	}
# function isIE() {
# var sAgent = window.navigator.userAgent;
# var Idx = sAgent.indexOf("MSIE"); if (Idx > 0) return true;
# else if (!!navigator.userAgent.match(/Trident\/7\./)) return true;
# else
# return false; }
# var infiniteScroll = false;
#                </script>
#                <script>
#                 var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
#                </script>
#                <script>
#                 googletag.cmd.push(function() {
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_Overaly_1x1', [1, 1], 'div-gpt-ad-1527225526136-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_Overaly_1x1', [1, 1], 'div-gpt-ad-1527169441053-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_LB', [[970, 90], [728, 90]], 'div-gpt-ad-1525929888153-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_CPD', [300, 250], 'div-gpt-ad-1521709628297-1').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_RT', [300, 250], 'div-gpt-ad-1521709628297-2').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_300x100_2', [300, 100], 'div-gpt-ad-1521709628297-5').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_BTF01', [300, 250], 'div-gpt-ad-1521709628297-7').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_BTF02', [300, 250], 'div-gpt-ad-1521709628297-8').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_HP_RB', [300, 250], 'div-gpt-ad-1521709628297-6').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_Text_640x65', [640, 65], 'div-gpt-ad-1525336073032-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_ROS_BTF03', [[300, 250], [336, 280]], 'div-gpt-ad-1532934634309-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_AT_Bottom02', [[300, 100], [300, 250], [336, 280], [320, 50]], 'div-gpt-ad-1532934750977-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_Interstitial', [1, 1], 'div-gpt-ad-1522819933630-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_AT_TOP', [320, 50], 'div-gpt-ad-1518418788389-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_AT_Middle', [[336, 280], [300, 250]], 'div-gpt-ad-1518418788389-1').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_AT_Bottom', [[336, 280], [300, 250]], 'div-gpt-ad-1518418788389-2').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_AT_Footer', [[300, 600], [300, 250], [320, 50], [336, 280]], 'div-gpt-ad-1518418788389-3').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[large, medium]')) {
# googletag.defineSlot('/22390678/Hindu_WAP_Inarticle_1x1', [1, 1], 'div-gpt-ad-1531980463264-0').addService(googletag.pubads());
# }
# if(isDeviceEnabled('[medium, small]')) {
# googletag.defineSlot('/22390678/Hindu_Desktop_Inarticle_1x1', [1, 1], 'div-gpt-ad-1552914402102-0').addService(googletag.pubads());
# }
# googletag.pubads().enableSingleRequest();
# googletag.pubads().setTargeting('Section', ['Science']);
# googletag.pubads().setTargeting('articleid', ['27898707']);
# googletag.pubads().enableLazyLoad();
# googletag.pubads().disableInitialLoad();
# googletag.enableServices();
# });
#                </script>
#                <script>
#                 if(isNonSubcribedUser()){ loadAsyncURL("https://go.automatad.com/geo/EwrTRc/afihbs.js"); }
#                </script>
#                <script>
#                 if(isNonSubcribedUser() && (DevIdf.isDesktop || DevIdf.isLargeDesktop)){ loadAsyncURL("https://saxp.zedo.com/sclient/tt3/fmos.js"); }
#                </script>
#                <script>
#                 var zmt_mtag;
# function zd_get_placements(){
# zmt_mtag = zmt_get_tag(2132,"283916");
# p283916_1 = zmt_mtag.zmt_get_placement("zt_283916_1", "283916", "1" , "87" , "16" , "1" ,"1", "1");
# zmt_mtag.zmt_set_async();
# zmt_mtag.zmt_load(zmt_mtag); }
#                </script>
#                <script type="text/javascript">
#                 if(isNonSubcribedUser()){
# window._taboola = window._taboola || [];
# _taboola.push({article:'auto', tracking:'utm_source=taboola'});
# _taboola.push({article :'auto'});
# !function (e, f, u, i) {
# if (!document.getElementById(i)){
# e.async = 1;
# e.src = u;
# e.id = i;
# f.parentNode.insertBefore(e, f);
# }
# }(document.createElement('script'),
# document.getElementsByTagName('script')[0],
# '//cdn.taboola.com/libtrc/thehindu-hindunews/loader.js',
# 'tb_loader_script');
# if(window.performance && typeof window.performance.mark == 'function')
# {window.performance.mark('tbl_ic');}
# }
#                </script>
#                <script type="text/javascript">
#                 if(isNonSubcribedUser()){
# window._taboola = window._taboola || [];
# _taboola.push({flush: true});
# }
#                </script>
#                <!-- Taboola Pixel Code -->
#                <script type="text/javascript">
#                 $(function(){
# if(isNonSubcribedUser()){
# window._tfa = window._tfa || [];
# window._tfa.push({notify: 'event', name: 'page_view', id: 1179651});
# !function (t, f, a, x) {
# if (!document.getElementById(x)) {
# t.async = 1;t.src = a;t.id=x;f.parentNode.insertBefore(t, f);
# }
# }(document.createElement('script'),
# document.getElementsByTagName('script')[0],
# '//cdn.taboola.com/libtrc/unip/1179651/tfa.js',
# 'tb_tfa_script');
# }
# });
#                </script>
#                <noscript>
#                 <img height="0" src="//trc.taboola.com/1179651/log/3/unip?en=page_view" style="display:none" width="0"/>
#                </noscript>
#                <!-- End of Taboola Pixel Code -->
#                <meta content="00762243DAFA333A5A6D97CE4545BDB2" name="msvalidate.01"/>
#                <meta content="ff4648e5089d361d" name="yandex-verification"/>
#                <meta content="6df5b97abf2ea60f2d4123265496b92b4faa009ceff5444e0b8482ebddd508d6" name="ahrefs-site-verification"/>
#                <meta content="true" name="branch:deeplink:show_journeys">
#                 <div class="overlay-screen">
#                 </div>
#                 <script>
#                  $(document).ready(function () {
# $('div.tag-button').each(function() {
# var x = $(this).find("a").text() ;
# var url = $("a",this).attr('href');
# var isAdded = false;
# var newtab = "";
# if(DevIdf.isDesktop || DevIdf.isLargeDesktop){
# newtab ='target="_blank"';
# }
# $('div[id^="content-body"] > p:not(:has(*))').each(function() {
# if(!isAdded){
# var re = new RegExp("((^" +x+"|"+ x + ")[,. ()] *)","i");
# if($(this).html().match(re) !=null){
# $(this).html($(this).html().replace( re, '<a href="' + url+ '?utm=bodytag' +'"'+ newtab +' ><strong>$1</strong></a>'));
# isAdded=true;
# }
# }
# });
# });
# });
#                 </script>
#                 <style>
#                  #audio_player {
# background: #133b5a;
# padding: 10px;
# margin-top: 10px;
# display: table;
# width: 100%;
# }
# .jp-audio, .jp-audio-stream{
# font-size: 16px;
# font-family: Verdana,Arial,sans-serif;
# line-height: 1.6;
# }
# .jp-interface {
# width: 100%;
# display: table;
# background: #231f20;
# padding: 5px;
# border-radius: 10px;
# }
# .jp-jplayer {
# background-color: #000;
# margin-right: 15px;
# float: left;
# }
# .jp-audio {
# width: calc(100% - 135px);
# float: left;
# }
# .audiologo {
# float: left;
# padding: 0 10px 10px 0;
# }
# .mobileaudiologo {display:none;}
# .audioplayerwrap {
# float: left;
# width: calc(100% - 90px);
# position: relative;
# }
# #seek-bar {
# width: calc(100% - 110px);
# height: 6px;
# display: inline-block;
# vertical-align: middle;
# border-radius: 15px;
# overflow: visible;
# background: #828282;
# cursor: pointer;
# }
# .jp-seek-bar {
# background: #828282;
# width: 100% !important;
# border-radius: 20px;
# height:100%
# }
# .jp-play-bar {
# background: #fff;
# position: relative;
# overflow: visible !important;
# border-radius: 20px;
# height:100%;
# width:0%;
# }
# .jp-play-bar:before ,.jp-volume-bar-value:before{
# content: "";
# width: 14px;
# height: 14px;
# position: absolute;
# border-radius: 100%;
# top: -4px;
# right: -10px;
# background: #2a5e88;
# overflow:visible !important;
# }
# #duarationtime{
# position: unset;
# float:right;
# clear:both;
# line-height: 32px;
# width: unset;
# }
# .jp-duration {
# float: left;
# display: inline;
# text-align: right;
# cursor: pointer;
# }
# .jp-current-time, .jp-duration {
# opacity: 0.8;
# font-family: Myriad Pro;
# font-size: 16px;
# text-align: right;
# color: rgba(255, 255, 255, 0.5);
# font-style: normal;
# float: left;
# }
# .timebar{
# float: left;
# display: inline;
# text-align: right;
# cursor: pointer;
# padding: 0 5px;
# opacity: 0.8;
# font-family: Myriad Pro;
# font-size: 16px;
# text-align: right;
# color: rgba(255, 255, 255, 0.5);
# }
# .jp-audio .jp-controls {
# padding: 0;
# display: inline-block;
# }
# .jp-toggles{display:none;}
# .audioplayicons a {
# position:relative;
# padding: 5px;
# font-size: 24px;
# line-height: 1.25;
# color: rgba(255, 255, 255, 0.3);
# }
# .audioplayicons a.jp-play{color:#fff;}
# .fa-step-backward:before {
# content: "\f048";
# }
# .fa-step-forward:before {
# content: "\f051";
# }
# .fa-forward:before {
# content: "\f04e";
# }
# .fa-backward:before {
# content: "\f04a";
# }
# .fa-volume-off:before {
# content: "\f026";
# }
# .fa-volume-down:before {
# content: "\f027";
# }
# .fa-share:before {
# content: "\f064";
# }
# .fa-code:before {
# content: "\f121";
# }
# .fa-copy:before, .fa-files-o:before {
# content: "\f0c5";
# }
# .fa-stop:before {
# content: "\f04d";
# }
# .jp-state-playing .jp-play .fa-play:before{
# content: "\f04c";
# }
# .audioplayicons {
# display: table;
# width: 100%;
# padding-top: 10px;
# border-top: 1px solid;
# clear: both;
# }
# #playlist{display:none;}
# .jp-volume-bar {
# background: #828282;
# width: calc(100% - 40px);
# height: 6px;
# border-radius: 20px;
# float: left;
# margin-top: 12px;
# cursor: pointer;
# overflow:visible;
# margin-right:10px;
# }
# .jp-volume-controls {
# position: unset;
# width: 35%;
# float: right;
# }
# .audioplayicons a.jp-mute {
# padding: 0 3px;
# width: 25px;
# display: inline-block;
# }
# .jp-state-muted .jp-mute .fa-volume-up:before{
# content: "\f026";
# }
# .jp-volume-bar-value{
# background: #fff;
# position: relative;
# height: 100%;
# border-radius: 20px;
# cursor: pointer;
# }
# .jp-title {
# color: #fff;
# }
# a#share {
# display: none;
# }
# #audiosharediv ul.audioshare {
# width: 100%;
# margin: 0;
# padding: 0;
# list-style-type: none;
# }
# #audiosharediv ul.audioshare li {
# display: inline-block;
# margin-right: 10px;
# }
# ul.audioshare li a {
# display: block;
# }
# ul.audioshare li a i {
# width: 45px;
# height: 45px;
# border: 1px solid;
# border-radius: 100%;
# padding: 13px;
# color: #fff;
# }
# ul.audioshare li .tw {
# background: #55acee;
# }
# ul.audioshare li .fb {
# background: #3b5998;
# }
# ul.audioshare li .wa {
# background: #43d854;
# }
# ul.audioshare li .mailaudio {
# background: #133b5a;
# }
# ul.audioshare li .redit{
# background: #828282;
# }
# ul.audioshare li .embedcode{
# background: #828282;
# }
# #audiosharediv{
# position: fixed;
# background: rgba(0, 0, 0, 0.5);
# top: 0;
# left: 0;
# width: 100%;
# height: 100%;
# z-index: 9999999;display:none;
# }
# .audiosharewrapper{
# position: relative;
# margin: 30px auto;
# width: 310px;
# top: 40%;
# background: #fff;
# padding: 15px 0px 10px 10px;
# }
# .textcode{
# width: 100%;
# padding-right: 10px;
# margin-top: 15px;
# display: table;
# }
# .copycode{
# float: right;
# color: #fff;
# background-color: transparent;
# border: 1px solid #828282;
# background: #828282;
# }
# .copycode:hover {
# background: #828282;
# }
# a#share:after {
# content: "Share";
# position: absolute;
# top: 5px;
# left: 30px;
# font-size: 16px;
# }
# .textcode textarea {
# resize: vertical;
# width: 100%;
# margin-bottom:10px;
# }
# @media (max-width: 767px) and (min-width: 1px) {
# .jp-jplayer{ width: 80px !important;
# height: 80px !important;
# margin: 10px;
# }
# .jp-jplayer img{ width: 80px !important;
# height: 80px !important;object-fit:contain;
# }
# .jp-audio {
# width: 100%;
# float: none;
# }
# .audioplayerwrap {
# width: 100%;
# }
# .seekbar {
# padding: 5px;
# }
# .jp-title {
# margin-bottom: 5px;
# height: 85px;
# overflow: hidden;
# padding: 10px 10px 10px 0;
# position: relative;
# }
# .audioplayicons {
# width: calc(100% - 50px);
# border-top: none;
# clear: both;
# float: left;
# }
# #audio_player {
# padding: 0px;
# }
# .jp-interface {
# border-radius: 0;
# }
# .mobileaudiologo {
# padding: 5px;
# width: 50px;
# float: left;
# display:block;
# }
# .jp-volume-controls {
# display:none;
# }
# a#share:after {
# top: 7px;
# left: 35px;
# }
# .audiologo {
# padding: 10px 10px 10px 0;
# width: 70px;
# }
# .audioplayicons a {
# font-size: 20px;
# }
# h4.jp-title:after {
# content: '';
# position: absolute;
# display: block;
# width: 80%;
# height: 16px;
# bottom: 0;
# z-index: 1;
# background: -moz-linear-gradient(top,rgba(19,59,90,0) 0,rgba(19,59,90,1) 19%);
# background: -webkit-linear-gradient(top,rgba(19,59,90,0) 0,rgba(19,59,90,1) 19%);
# background: linear-gradient(to right,rgba(255,255,255,0) 0,rgb(19, 59, 90) 50%,rgb(19, 59, 90) 100%);
# right: 0;
# }
# }
#                 </style>
#                 <style type="text/css">
#                  span.footer-nav-heading.blue-color a {
# color: #7e7c76;
# font-size: 11.5px;
# }
# .entrySubs {
# z-index: 9999;
# }
# .dfp-ad div {
# clear: both;
# }
# header.sticky .main-menu.clear{
# z-index: 9999999999 !important;
# }
# .addblockersection .callout{
# width: 100%;
# padding: 10px;
# }
# .Inarticle div{
# margin-bottom: 0;
# }
# .dfp-ad ~ .subs-promoted-story {
# width: 300px;
# height: 250px;
# margin: 0 auto 20px;
# clear:both;
# }
# /* New text -Start #main-menu>ul>li:nth-child(3){position:relative;}
# #main-menu>ul>li:nth-child(3):after {
# content: " New!";
# top: -8px;
# left: 37px;
# color: rgb(255, 0, 31);
# font-size: 10px;
# font-family: 'Fira Sans', sans-serif; font-weight:600;
# position: absolute;
# } .dfp-ad {
# float: left;
# }
# New text - End*/
# @media (max-width: 420px){
# body {
# overflow-x: hidden;
# overflow-y: scroll;
# }
# body>div.container-main {
# overflow-x: hidden;
# overflow-y: auto;
# }
# }
# /* Mydashboard-Start*/
# #mobilesignin li.dropdown:hover .dropdown-menu {
# display: block !important;
# }
# #mobilesignin .dropdown-menu:after {
# bottom: 100%;
# left: auto;
# right: 12%;
# border: solid transparent;
# content: " ";
# height: 0;
# width: 0;
# position: absolute !important;
# pointer-events: none;
# border-color: rgba(136,183,213,0);
# border-bottom-color: #fff;
# border-width: 8px;
# margin-left: -5px;
# }
# #mobilesignin .dropdown-menu{
# min-width:auto !important;
# right: 35px;
# padding: 0px 20px;
# }
# #mobilesignin .dropdown-menu {
# top: 38px;
# }
# #mobilesignin .dropdown-menu li {
# padding:5px;
# }
# #mobilesignin .dropdown-menu li a{
# display:block;
# }
# @media only screen and (max-width: 767px) and (min-width: 1px) {
# .author-bottom {padding: 20px 0 0px 6px;
# /*padding-left: 6px;*/
# position: relative;
# /*margin: 0px;*/
# width: 100%;
# border-top: 0px solid #d1ced2;
# }
# }
# @media( min-width : 480px) and (max-width:768px) {
# #mobilesignin .dropdown-menu{
# min-width:auto !important;
# right: 0px;
# padding: 0px 20px;
# }
# #mobilesignin .dropdown-menu:after {
# right: 0%;
# }
# }
# /* Mydashboard-End*/
# @media(max-width: 420px) {
# div[id^='content-body-'] .ng_header{
# width: 100%;
# }
# }
# .article-block-multiple .live-snippet-border{overflow: visible;}
# .dropdown {
# top: auto !important;
# }
# .microsite-sections {
# width: 87%;
# }
# .timebar {
# cursor: default;
# }
# .audioplayicons a:hover {
# color: #fff;
# }
# .jp-current-time, .jp-duration {
# cursor: default;
# }
# @media (max-width: 1599px){
# .article h2.special-article-heading{
# width: 600px !important;
# }
# }
# @media(max-width :1023px) and (min-width:768px){
# .article h2.special-article-heading{
# width: 670px !important;
# }
# }
# @media ( max-width : 1024px) and (min-width: 768px) {
# .jp-volume-controls {
# display: none;
# }
# button.ui-datepicker-trigger {
# width: 13px;
# height: 28px;
# z-index: 99999999;
# }
# }
# @media ( max-width : 767px) {
# button.ui-datepicker-trigger {
# width: 13px;
# height: 28px;
# z-index: 99999999;
# }
# .date-picker-cont {
# width: 175px;
# }
# #stickyfooterarticle .slick-list {
# padding: 0;
# }
# }
# @media ( min-width : 1239px) {
# .sticky li.dropdown.ssologin:after {
# bottom:15px;
# }
# li.dropdown.signinbtn:after {
# color: #ff001f !important;
# font-size: 12px !important;
# }
# header.sticky li.dropdown.signinbtn:after {
# color: #ff001f !important;
# font-size: 10px !important;
# }
# }
# header.article-header-cont.sticky .subsEntrymenu {
# display: none !important;
# }
# li.dropdown.signinbtn:after {
# text-transform: uppercase;
# }
# .story-card-33-news::before{background: -moz-linear-gradient(top, rgba(255,255,255,0) 0%, rgba(255,255,255,1) 100%); /* FF3.6-15 */
# background: -webkit-linear-gradient(top, rgba(255,255,255,0) 0%,rgba(255,255,255,1) 100%); /* Chrome10-25,Safari5.1-6 */
# background: linear-gradient(to bottom, rgba(255,255,255,0) 0%,rgba(255,255,255,1) 100%); /* W3C, IE10+, FF16+, Chrome26+, Opera12+, Safari7+ */
# filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#00ffffff', endColorstr='#ffffff',GradientType=0 ); /* IE6-9 */}
# @media print{
# ._yeti_main_container _left, ._yeti_ad_container, #taboola-below-article-thumbnails, .trc_rbox_container{display: none;}
# }
# @media (max-width: 767px) and (min-width: 1px){
# .article h2.special-article-heading {
# width: 90%!important;
# }
# .infobox-container {
# width: 100%;
# margin-left: 0;
# margin-right: 0;
# border-bottom: none; padding: 10px;
# }
# }
# .more-05{position: relative !important;}
# .resource3s-container{height:auto !important;}
#                 </style>
#                 <script>
#                  function appURL(){	return "https://www.thehindu.com/";
# }
# function pagesource(){
# return "article-page-science";
# }
# function PageSourceType(){
# return "articlepage";
# }
#                 </script>
#                 <script>
#                  var w=window;if(w.performance||w.mozPerformance||w.msPerformance||w.webkitPerformance){var d=document;AKSB=w.AKSB||{},AKSB.q=AKSB.q||[],AKSB.mark=AKSB.mark||function(e,_){AKSB.q.push(["mark",e,_||(new Date).getTime()])},AKSB.measure=AKSB.measure||function(e,_,t){AKSB.q.push(["measure",e,_,t||(new Date).getTime()])},AKSB.done=AKSB.done||function(e){AKSB.q.push(["done",e])},AKSB.mark("firstbyte",(new Date).getTime()),AKSB.prof={custid:"399806",ustr:"",originlat:"0",clientrtt:"514",ghostip:"23.32.20.28",ipv6:false,pct:"10",clientip:"183.83.229.31",requestid:"3c05db4e",region:"20734",protocol:"",blver:14,akM:"dscf",akN:"ae",akTT:"O",akTX:"1",akTI:"3c05db4e",ai:"433509",ra:"false",pmgn:"",pmgi:"",pmp:"",qc:""},function(e){var _=d.createElement("script");_.async="async",_.src=e;var t=d.getElementsByTagName("script"),t=t[t.length-1];t.parentNode.insertBefore(_,t)}(("https:"===d.location.protocol?"https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js")}
#                 </script>
#                </meta>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="">
#   <noscript id="deferred-styles">
#    <link href="https://th.thgim.com/static/theme/default/base/css/lazystyles.c63765e9d161eccffe0af55bebca8d80.min.css" rel="stylesheet"/>
#    <link href="https://th.thgim.com/static/css/print.min.css" media="print" rel="stylesheet" type="text/css">
#    </link>
#   </noscript>
#   <script>
#    var loadDeferredStyles = function() {
# var addStylesNode = document.getElementById("deferred-styles");
# var replacement = document.createElement("div");
# replacement.innerHTML = addStylesNode.textContent;
# document.body.appendChild(replacement)
# addStylesNode.parentElement.removeChild(addStylesNode);
# };
# var raf = window.requestAnimationFrame || window.mozRequestAnimationFrame ||
# window.webkitRequestAnimationFrame || window.msRequestAnimationFrame;
# if (raf) raf(function() { window.setTimeout(loadDeferredStyles, 0); });
# else window.addEventListener('load', loadDeferredStyles);
#   </script>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-W5VV9N" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    $(function(){(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W5VV9N');});
#   </script>
#   <!-- End Google Tag Manager -->
#   <section class="">
#    <div id="24254344">
#     <script type="text/javascript">
#      new function(d) {
# var adcode = "<!-- Ad Slot 1 tag: --> " +
# "<!-- begin ZEDO for channel:- HIndu_Interstitial, Publisher: Hindu, Ad Dimension: Intromercial-1x1 --> " +
# "<div id=\"zt_283916_1\" style=\"display:show;height:0px;\"> " +
# "<" + "script id=\"zt_283916_1\" language=\"javascript\"> " +
# "" +
# "if(typeof zmt_mtag !='undefined' && typeof zmt_mtag.zmt_render_placement !='undefined')" +
# "{" +
# " zmt_mtag.zmt_render_placement(p283916_1);" +
# "}" +
# "<" + "/script>" +
# "</div>" +
# "<!-- end ZEDO for channel: - HIndu_Interstitial, Publisher: Hindu, Ad Dimension: Intromercial-1x1 --> ";	if(isDeviceEnabled("[medium, small]") && isNonSubcribedUser()) {
# d.write(adcode);
# }
# }(document);
#     </script>
#    </div>
#    <!-- Begin DFP : /22390678/Hindu_WAP_Interstitial, publisher: The Hindu -->
#    <div class="dfp-ad" id="div-gpt-ad-1522819933630-0" style="height:0px !important;margin-bottom: 0px;">
#     <script>
#      if(isDeviceEnabled("[large, medium]") && isNonSubcribedUser()) {
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1522819933630-0'); });
# }
#     </script>
#    </div>
#    <!-- End DFP : /22390678/Hindu_WAP_Interstitial, publisher: The Hindu -->
#    <!-- Begin DFP : /22390678/Hindu_Desktop_Overaly_1x1, publisher: The Hindu -->
#    <div class="dfp-ad" id="div-gpt-ad-1527225526136-0" style="height:0px !important;margin-bottom: 0px;">
#     <script>
#      if(isDeviceEnabled("[medium, small]") && isNonSubcribedUser()) {
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1527225526136-0'); });
# }
#     </script>
#    </div>
#    <!-- End DFP : /22390678/Hindu_Desktop_Overaly_1x1, publisher: The Hindu -->
#    <!-- Begin DFP : /22390678/Hindu_WAP_Overaly_1x1, publisher: The Hindu -->
#    <div class="dfp-ad" id="div-gpt-ad-1527169441053-0" style="height:0px !important;margin-bottom: 0px;">
#     <script>
#      if(isDeviceEnabled("[large, medium]") && isNonSubcribedUser()) {
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1527169441053-0'); });
# }
#     </script>
#    </div>
#    <!-- End DFP : /22390678/Hindu_WAP_Overaly_1x1, publisher: The Hindu -->
#    <div class="top-add hidden-xs hidden-sm ad-box">
#     <!-- Begin DFP : /22390678/Hindu_Desktop_HP_LB, publisher: The Hindu -->
#     <div class="dfp-ad" id="div-gpt-ad-1525929888153-0" style="">
#      <script>
#       if(isDeviceEnabled("[medium, small]") && isNonSubcribedUser()) {
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1525929888153-0'); });
# }
#      </script>
#     </div>
#     <!-- End DFP : /22390678/Hindu_Desktop_HP_LB, publisher: The Hindu -->
#    </div>
#   </section>
#   <div class="container-main">
#    <header class="article-header-cont" role="banner">
#     <div class="container">
#      <div class="row">
#       <div class="col-sm-12 col-xs-12">
#        <section class="header-top clear hidden-xs">
#         <div class="small-logo">
#          <a href="https://www.thehindu.com/">
#           <img alt="Return to frontpage" src="https://th.thgim.com/static/theme/default/base/img/logo.png"/>
#          </a>
#         </div>
#         <div class="search-block">
#          <form action="https://www.thehindu.com/search/">
#           <input autocomplete="off" data-type="search" name="q" oninput="setCustomValidity('')" oninvalid="setCustomValidity('Please enter your search text.')" pattern=".*\S+.*" placeholder="Search here" required="" title="Please enter your search text" type="text"/>
#           <button class="fa fa-search search-selection-icon" style="background: none !important; color: black">
#           </button>
#           <input name="order" type="hidden" value="DESC"/>
#           <input name="sort" type="hidden" value="publishdate"/>
#          </form>
#         </div>
#         <!-- [Socialize] -->
#         <div class="socialize hidden-xs">
#          <ul>
#           <li>
#            <a class="fb" href="https://www.facebook.com/thehindu" target="_blank" title="Connect on Facebook">
#             <i class="fa fa-facebook">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="tw" href="https://twitter.com/The_Hindu" target="_blank" title="Follow on Twitter">
#             <i class="fa fa-twitter">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="in" href="https://www.linkedin.com/school/the-hindu/" target="_blank" title="Connect on Linkedin">
#             <i class="fa fa-linkedin">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="ins" href="https://instagram.com/the_hindu/?ref=badge" target="_blank" title="Follow on Instagram">
#             <i class="fa fa-instagram">
#             </i>
#            </a>
#           </li>
#           <li>
#            &lt;
#            <a class="usernews" href="https://www.thehindu.com/newsletter-subscription/" target="_blank" title="Subscribe to our Newsletter">
#             <i class="fa fa-envelope">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="user androidos" href="https://www.thehindu.com/social/" title="Install our Android &amp; iOS apps">
#             <i class="fa fa-mobile">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a class="ePaper" href="https://epaper.thehindu.com/?utm_source=The_Hindu_Website&amp;utm_medium=CPC&amp;utm_campaign=HomePageLink" title="ePaper">
#             ePaper
#            </a>
#           </li>
#           <!-- <li><a href="https://epaper.thehindu.com/?utm_source=Thehindu.com&utm_medium=MotherDomain&utm_campaign=TheHindu" class="user" title="ePaper"><i class="fa fa-newspaper-o"></i></a></li> -->
#          </ul>
#         </div>
#         <!-- [/Socialize] -->
#        </section>
#        <div class="logo-block hidden-lg hidden-md hidden-sm">
#         <div class="logo" id="logo">
#          <a href="https://www.thehindu.com/">
#           <img alt="Return to frontpage" src="https://th.thgim.com/static/theme/default/base/img/logo.png"/>
#          </a>
#         </div>
#        </div>
#        <div class="100_3x_JustIn hidden-xs">
#         <div class="justin-100x3-container justin-article-header">
#          <span class="cutout-arrow-1">
#          </span>
#          <span class="cutout-arrow-2">
#          </span>
#          <span class="cutout-arrow-3">
#          </span>
#          <span class="cutout-arrow-4">
#          </span>
#          <span class="justIn-heaing">
#           Just In
#          </span>
#          <ul class="justin-slider" data-category="just-in " data-label="article-page-science">
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/news/national/other-states/nia-team-seizes-huge-cache-of-arms-and-ammunition-in-manipur/article27899668.ece">
#             <span class="justIn-number">
#             </span>
#             <span class="red-color">
#              <i class="fa fa-clock-o">
#              </i>
#              <span>
#               5mins
#              </span>
#             </span>
#             NIA team seizes huge cache of arms and ammunition in Manipur
#            </a>
#           </li>
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/news/national/pm-modi-meets-chinese-president-xi-in-bishkek/article27899666.ece">
#             <span class="justIn-number">
#             </span>
#             <span class="red-color">
#              <i class="fa fa-clock-o">
#              </i>
#              <span>
#               6mins
#              </span>
#             </span>
#             PM Modi meets Chinese President Xi Jinping on sidelines of SCO in Bishkek
#            </a>
#           </li>
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/business/markets/gold-remains-flat-silver-slides-on-reduced-offtake/article27899506.ece">
#             <span class="justIn-number">
#             </span>
#             <span class="red-color">
#              <i class="fa fa-clock-o">
#              </i>
#              <span>
#               21mins
#              </span>
#             </span>
#             Gold remains flat; silver slides on reduced offtake
#            </a>
#           </li>
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/news/national/other-states/three-brothers-get-life-term-in-ups-muthber-village-murder-case/article27899382.ece">
#             <span class="justIn-number">
#             </span>
#             <span class="red-color">
#              <i class="fa fa-clock-o">
#              </i>
#              <span>
#               26mins
#              </span>
#             </span>
#             Three brothers get life term in UP’s Muthber village murder case
#            </a>
#           </li>
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/business/markets/sensex-ends-marginally-lower-in-choppy-trade-yes-bank-tanks-13/article27899378.ece">
#             <span class="justIn-number">
#             </span>
#             <span class="red-color">
#              <i class="fa fa-clock-o">
#              </i>
#              <span>
#               27mins
#              </span>
#             </span>
#             Sensex ends marginally lower in choppy trade; Yes Bank tanks 13%
#            </a>
#           </li>
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/news/national/aiims-resident-doctors-to-boycott-work-on-friday/article27898785.ece">
#             <span class="justIn-number">
#             </span>
#             <span class="red-color">
#              <i class="fa fa-clock-o">
#              </i>
#              <span>
#               1hr
#              </span>
#             </span>
#             AIIMS resident doctors to boycott work on June 14
#            </a>
#           </li>
#           <li class="justin-slide">
#            <a class="justIn-story" href="https://www.thehindu.com/news/international/sajid-javid-signs-us-extradition-order-for-julian-assange/article27898645.ece">
#             <span class="justIn-number">
#             </span>
# ...
# });
# $(".addExploreBtn").click(function() {
# location.href = "https://subscription.thehindu.com/subscription?utm_source=adblocker&utm_medium=subscribtionbutton&utm_campaign=adblocker";
# });
# });
#     </script>
#    </footer>
#   </div>
#   <script type="text/javascript">
#    //<![CDATA[
# var clientDT = new Date().getTime();
# document.write('<img style="display:none;" src="https://www.thehindu.com/analysis-logger/Logger?rt=1&ctxId=309&contextPath=16-301-309-&pubId=2&cat=&meta=read-story&objId=27898707&type=article&title=India+to+have+a+separate+space+station%3a+ISRO&url=https%3a%2f%2fwww.thehindu.com%2fsci-tech%2fscience%2findia-to-have-a-separate-space-station-isro%2farticle27898707.ece&amp;clientDT=' + clientDT + '" alt="" width="1" height="1"/>');
# //]]>
#   </script>
#   <noscript>
#    <div>
#     <img alt="one pixel graphics" height="1" src="https://www.thehindu.com/analysis-logger/Logger?rt=1&amp;ctxId=309&amp;contextPath=16-301-309-&amp;pubId=2&amp;cat=&amp;meta=read-story&amp;objId=27898707&amp;type=article&amp;title=India+to+have+a+separate+space+station%3a+ISRO&amp;url=https%3a%2f%2fwww.thehindu.com%2fsci-tech%2fscience%2findia-to-have-a-separate-space-station-isro%2farticle27898707.ece" width="1"/>
#    </div>
#   </noscript>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /*Device width fix for Windows Phone 8 and IE 10*/
# if (navigator.userAgent.match(/IEMobile\/10\.0/)) {
# var msViewportStyle = document.createElement("style")
# msViewportStyle.appendChild(
# document.createTextNode(
# "@-ms-viewport{width:auto!important}"
# )
# )
# document.getElementsByTagName("head")[0].appendChild(msViewportStyle)
# }
#   </script>
#   <!-- custom mordenizr, can be changed if required by cms. We are currently only using no-csscolumn. Later we may need to use other elements also
# <script src="https://th.thgim.com/static/js/modernizr.js"></script>-->
#   <script src="https://th.thgim.com/static/js/wf-site.ea977f0fbadb948e94494c035b391a1a.min.js" type="text/javascript">
#   </script>
#   <script src="https://th.thgim.com/static/js/lib/slick.min.js">
#   </script>
#   <script>
#    (function ($, d) {
# $.each(readyQ, function (i, f) {
# $(f)
# });
# $.each(bindReadyQ, function (i, f) {
# $(d).bind("ready", f)
# })
# })(jQuery, document)
#   </script>
#   <!-- User Data Capture start -->
#   <!-- User Data Capture end -->
#   <script async="" src="https://dm.thehindu.com/feeder/v2/js/feed.js" type="text/javascript">
#   </script>
#   <script>
#    var RecAdvtFillerURL ="https://tai.thehindu.com/mydashboard/userreco/hindu?siteid="+siteId+"&size=10&recotype=all&aid=27898707&userid="+isUserDetails.userId;
# var EditAdvtFillerURL = "https://www.thehindu.com/feeder/advtfiller.json";
# var EditLabel = "Recommended by The Hindu"
#   </script>
#   <script src="https://th.thgim.com/static/theme/default/base/js/default-base.78b9700b9bc1cd52ed6c38e57fee0b80.min.js">
#   </script>
#   <script>
#    require.config({
# // Local Directory
# baseUrl: "https://th.thgim.com/static/js",
# // Script Locations
# paths: {
# "jquery":"https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min",
# "jquery-ui":"jquery-ui-1.12.1.min",
# "slick": "https://th.thgim.com/static/js/lib/slick.min",
# "dateformat":"jquery-dateFormat.min",
# "d3": "d3.min",
# "jplayer": "jquery.jplayer.min",
# "jplayerlist": "jplayer.playlist.min",
# "marquee": "jquery.marquee.min",
# "tipTip": "jquery.tipTip.min",
# "jscroll": "jquery.jscroll.default.min",
# "magnificpopup": "jquery.magnific-popup.min",
# "jquerymobile": "jquery.mobile.min",
# "jqueryautocomplete": "jquery.autocomplete.min",
# "jquerydataTables": "jquery.dataTables.min",
# "jqueryslimscroll":"jquery.slimscroll.min",
# "topojson":"topojson.v2.min"
# },
# waitSeconds:0
# });
#   </script>
#   <script>
#    var Adblock = true;
#   </script>
#   <script src="https://th.thgim.com/static/js/ads.min.js" type="text/javascript">
#   </script>
#   <script>
#    if (isNonSubcribedUser() && Adblock && location.hostname.indexOf(".com") > 0) {
# document.body.style.overflow = "hidden";
# $('.overlay').addClass('overlayblock');
# $('.addblockersection').addClass('enableaddblockersection');
# ga('send', 'event', "AdBlock", "AdBlock PopUp", "AdBlock PopUp View", {
# nonInteraction : true
# });
# if(typeof sendTaiData !== "undefined" ) {
# taiDataObject['etime'] = "" + new Date().getTime();
# taiDataObject['adblock'] = "adblock_popup_view";
# taiData.push(taiDataObject);
# sendTaiData(taiData, 'adblocker');
# }
# }
#   </script>
#   <script>
#    $(document).ready(function (e) {
# $(document).on("makeSocialShareReady", function(event, data) {
# var selector = $(data).find(".hover-social-media-top ul li, .hover-social-media-bottom ul li");
# $(selector).on('click', function (e) {
# var shareUrl = $(this).parents('[data-share-url]').data('share-url');
# var shareText = $(this).parents('[data-share-url]').data('share-text');
# var shareValue ="";
# if ($(this).find('i').hasClass('fa-facebook')) {
# shareValue = "facebook";
# openShareLink('http://www.facebook.com/sharer/sharer.php?u=' + encodeURIComponent(shareUrl));
# } else if ($(this).find('i').hasClass('fa-twitter')) {
# shareValue = "twitter";
# openShareLink('http://twitter.com/share?text=' + encodeURIComponent(shareText) + '&url=' + encodeURIComponent(shareUrl));
# }
# if(typeof sendTaiData !== "undefined" && shareValue != "") {
# taiDataObject['share'] = shareValue;
# taiDataObject['etime'] = "" + new Date().getTime();
# taiData.push(taiDataObject);
# sendTaiData(taiData, 'share');
# }
# });
# });
# $(document).on('pageContentReady', function (event, content) {
# $(document).trigger( "makeSocialShareReady", content );
# });
# });
# $(document).ready(function (e) {
# $(document).trigger( "makeSocialShareReady", $('body') );
# });
# function openShareLink(pLink) {
# var popUp = window.open(pLink, 'popupwindow', 'scrollbars=yes,width=740,height=400');
# popUp.focus();
# return false;
# }
#   </script>
#   <script>
#    var articleShareData = {};
# var excludeShareClickList = ["fa-whatsapp", "fa-envelope", "fa-comment"];
# $(document).ready(function(){
# $(document).on("articleSocialShareReady", function(event, data) {
# var font_key = "article_font_id";
# $(data).find(".edite-text-cont").on("click", " a:not(.active)", function(e){
# var prevActiveId = $(".edite-text-cont a.active").attr('id');
# $(".article-cont").removeClass( $("a#"+prevActiveId).data('parent-class') ).addClass( $(this).data('parent-class') );
# hinduStore.save(font_key, $(this).attr('id'), 1);
# $(".edite-text-cont a").removeClass('active');
# $(".edite-text-cont a#" + $(this).attr('id')).addClass('active');
# });
# var tmpObj = hinduStore.get(font_key);
# if(!tmpObj){
# tmpObj = "medium";
# } else {
# tmpObj = tmpObj.value;
# }
# $(data).find(".edite-text-cont a#" + tmpObj).click();
# });
# });
#   </script>
#   <script>
#    $(document).ready(function(){
# $('.share-more-icon').on('click', function() {
# $(this).next('.share-more').slideToggle();
# });
# $('.close-share-more').on('click', function() {
# $(this).parent('.share-more').slideToggle();
# });
# });
#   </script>
#   <script>
#    $(document).ready(function(e){
# $(document).on("articleSocialShareReady", function(event, data) {
# var selector = $(data).find("ul.aricle-share:last li a");
# $(selector).on('click',function(e){
# if($(this).find('i').hasClass('fa-print')) {
# window.print();
# } else {	var targetClass = $(this).find("i").attr("class").split(" ")[1];
# if(excludeShareClickList.indexOf(targetClass) === -1 ) {
# if(typeof sendTaiData !== "undefined" ) {
# taiDataObject['share'] = targetClass.split("-")[1];
# taiDataObject['etime'] = "" + new Date().getTime();
# taiData.push(taiDataObject);
# sendTaiData(taiData, 'share');
# }
# var id = $(".jscroll-inner>.active .articlepage").data("artid") + "-" + targetClass;
# openShareLink(articleShareData[id]);
# }
# }
# });
# });
# // pointing sticky share click to article share click.
# $("ul.aricle-sticky-share li a").on('click',function(e){
# var targetClass = $(this).find("i").attr("class").split(" ")[1];
# if(excludeShareClickList.indexOf(targetClass) === -1 ) {
# $(".jscroll-inner>.active .articlepage ul.aricle-share li a i." + targetClass).parent('a').click();
# }
# });
# function openShareLink(pLink, target) {
# var popUp = window.open(pLink, 'popupwindow', 'scrollbars=yes,width=740,height=400');
# popUp.focus();
# return false;
# }
# });
#   </script>
#   <script>
#    $(document).ready(function(e){
# $(document).on("articleSocialShareReady", function(event, data) {
# var url = $(data).find(".aricle-share").data("shareUrl");
# var text = $(data).find(".aricle-share").data("shareText");
# var articleId = $(data).data("artid");
# var selectorArray = new Array();
# selectorArray.push("articlepage:last .aricle-share");
# selectorArray.push("sticky-article-heading[data-artid='27898707'] .aricle-sticky-share");
# var getOrApply = function(value, context) {
# if($.isFunction(value)) {
# return value.apply(context, $.makeArray(arguments).slice(2));
# }
# return value;
# };
# var URL_PARAMS_REGEX = /(&?[a-zA-Z0-9]+=)?\{([a-zA-Z0-9]+)\}/g;
# var MEASURES = {
# "G": 1000000000,
# "M": 1000000,
# "K": 1000
# };
# _renderShareCount = function(share, container) {
# var $count = $(container).next('.cnt');
# this._loadCount(share).done($.proxy(function(count) {
# if(count) {
# $count.text(count);
# }
# }, this));
# }
# _loadCount = function(share) {
# var deferred = $.Deferred();
# var countUrl = this._getCountUrl(share);
# if(!countUrl) {
# return deferred.resolve(0).promise();
# }
# var handleSuccess = $.proxy(function(response) {
# deferred.resolve(this._getCountValue(response, share));
# }, this);
# $.getJSON(countUrl).done(handleSuccess)
# .fail(function() {
# $.get(countUrl).done(handleSuccess)
# .fail(function() {
# deferred.resolve(0);
# });
# });
# return deferred.promise();
# }
# _getShareUrl = function(share) {
# var shareUrl = getOrApply(share.shareUrl, share);
# return this._formatShareUrl(shareUrl, share);
# }
# _getCountUrl = function(share) {
# var countUrl = getOrApply(share.countUrl, share);
# return this._formatShareUrl(countUrl, share);
# }
# _getCountValue = function(response, share) {
# var count = ($.isFunction(share.getCount) ? share.getCount(response) : response) || 0;
# return (typeof count === "string") ? count : this._formatNumber(count);
# }
# _formatNumber = function(number) {
# $.each(MEASURES, function(letter, value) {
# if(number >= value) {
# number = parseFloat((number / value).toFixed(2)) + letter;
# return false;
# }
# });
# return number;
# }
# _formatShareUrl = function(url, share) {
# return url.replace(URL_PARAMS_REGEX, function(match, key, field) {
# var value = share[field] || "";
# return value ? (key || "") + window.encodeURIComponent(value) : "";
# });
# }
# _createSelector = function(identifier) {
# var tmp = "";
# for(var i=0; i<selectorArray.length; i++) {
# tmp += "."+selectorArray[i]+" ."+identifier;
# if(selectorArray.length > 1 && i < (selectorArray.length - 1))
# tmp += ", ";
# }
# return tmp;
# }
# var tmpCards = new Array();
# var tmpArray = ["facebook", "twitter", "reddit", "whatsapp", "webwhatsapp", "email"];
# for(i = 0; i < tmpArray.length; i++) { tmpCards.push(socialCards[tmpArray[i]]);
# }
# $.each(tmpCards, function(index){
# var share = tmpCards[index];
# share.url = url;
# share.text = text;
# _renderShareCount(share, _createSelector(share.faClass));
# sUrl = _getShareUrl(share);
# // share.shareUrl = sUrl;
# var tmpKey = articleId + "-" + share.faClass;	articleShareData[tmpKey] = sUrl;
# });
# var share = socialCards.whatsapp;
# var shareUrl = articleShareData[articleId + "-" + share.faClass];
# shareUrl += window.encodeURIComponent("?utm_campaign=article_share&utm_medium=referral&utm_source=whatsapp.com");
# $(data).find('.fa-whatsapp.wa').parent().attr("href", shareUrl)
# .attr("target", "_" + share.shareIn);	$(".sticky-article-heading ul.aricle-sticky-share li i.fa-whatsapp.wa").parent().attr("href", shareUrl)
# .attr("target", "_" + share.shareIn);
# share = socialCards.email;
# shareUrl = articleShareData[articleId + "-" + share.faClass];
# $(data).find('.fa-envelope.en').parent().attr("href", shareUrl)
# .attr("target", "_" + share.shareIn);
# $(".sticky-article-heading ul.aricle-sticky-share li i.fa-envelope.en").parent().attr("href", shareUrl)
# .attr("target", "_" + share.shareIn);
# });	});
# $(document).ready(function (e) {
# $(document).trigger( "articleSocialShareReady", $('.articlepage:last'));
# });
# var socialCards = {
# facebook: {
# faClass : 'fa-facebook',
# shareUrl: "https://facebook.com/sharer/sharer.php?u={url}",
# countUrl: function() {
# return "https://graph.facebook.com/?id={url}";
# },
# getCount: function(data) {
# return (data.share && data.share.share_count) || 0;
# }
# },
# googleplus: {
# faClass : 'fa-google-plus',
# shareUrl: "https://plus.google.com/share?url={url}",
# countUrl: function() {
# return "https://cors-anywhere.herokuapp.com/https://plusone.google.com/_/+1/fastbutton?url="+ window.encodeURIComponent(this.url);
# },
# getCount: function(data) {
# return parseFloat((data.match(/\{c: ([.0-9E]+)/) || [])[1]);
# }
# },
# linkedin: {
# faClass : 'fa-linkedin',
# shareUrl: "https://www.linkedin.com/shareArticle?mini=true&url={url}",
# countUrl: "https://www.linkedin.com/countserv/count/share?format=jsonp&url={url}&callback=?",
# getCount: function(data) {
# return data.count;
# }
# },
# pinterest: {
# faClass : 'fa-pinterest-p',
# shareUrl: "https://pinterest.com/pin/create/bookmarklet/?media={media}&url={url}&description={text}",
# countUrl: "https://api.pinterest.com/v1/urls/count.json?&url={url}&callback=?",
# getCount: function(data) {
# return data.count;
# }
# },
# stumbleupon: {
# faClass : 'fa-stumbleupon',
# shareUrl: "http://www.stumbleupon.com/submit?url={url}&title={title}",
# countUrl: "https://cors-anywhere.herokuapp.com/https://www.stumbleupon.com/services/1.01/badge.getinfo?url={url}",
# getCount: function(data) {
# return data.result.views;
# }
# },
# twitter: {
# faClass : 'fa-twitter',
# shareUrl: "https://twitter.com/share?url={url}&text={text}&via={via}&hashtags={hashtags}",
# countUrl: ""
# },
# whatsapp: {
# faClass: "fa-whatsapp",
# shareUrl: "whatsapp://send?text={text} {url}",
# countUrl: "",
# shareIn: "self"
# },
# webwhatsapp: {
# faClass: "fa-whatsapp",
# shareUrl: "https://api.whatsapp.com/send?text={text} {url}",
# countUrl: "",
# shareIn: "self"
# },
# email: {
# faClass : 'fa-envelope',
# shareUrl: "mailto:{to}?subject={text}&body={url}",
# countUrl: "",
# shareIn: "self"
# },
# gmail: {
# faClass : 'fa-envelope',
# shareUrl: "https://mail.google.com/mail/u/0/?view=cm&fs=1&to=&su={text}&body={url}",
# countUrl: "",
# shareIn: "blank"
# },
# reddit: {
# faClass : 'fa-reddit-alien',
# shareUrl: "https://reddit.com/submit?url={url}&title={title}",
# countUrl: "https://www.reddit.com/api/info.json?url=",
# getCount: function(response) {
# var childrens = response.data.children;
# if(childrens.length > 0) {
# if(childrens[0].hasOwnProperty("data")) {
# return childrens[0].data.score;
# }
# }
# return "";
# }
# }
# }
#   </script>
#   <script>
#    function publist(item) {
# url = "https://www.thehindu.com/";
# id = "2";
# switch (item) {
# case "url":
# item = url;
# break;
# case "id":
# item = id;
# break;
# default:
# }
# return item;
# }
#   </script>
#   <script>
#    var VUUKLE_HOST=window.location.hostname.replace("www.","").replace(/^(m\.)/,"");
# var VUUKLE_CONFIG = {
# "apiKey": "432081eb-6e8e-4abc-a88f-ca5357aa7244",
# "host": VUUKLE_HOST,
# "articleId": "27898707",
# "img": "https://www.thehindu.com/sci-tech/science/vkf7rv/article26423945.ece/ALTERNATES/LANDSCAPE_100/SPACE-NASA",
# "tags": "sci-tech,science",
# "url": "https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece",
# "title": "India to have a separate space station: ISRO",
# "language": "en",
# "globalRecommendations": false,
# "recommendationsWideImages": false,
# "darkMode": false,
# "color": "1f57a5",
# ads: {
# enabled: isNonSubcribedUser()
# },
# "comments": {
# "enabled": true,
# "hideRecommendedArticles": !isNonSubcribedUser(),
# "socialAuth": true,
# "vuukleAuth": true,
# "sorting": "latest",
# "transliteration": {
# "language": "en",
# "enabledByDefault": false
# },
# "hideCommentInputBox": false,
# "commentingClosed": false,
# "maxChars": 1000,
# "countToLoad": 1,
# "toxicityLimit": 80,
# "customText": {}
# }
# };
# (function() {
# var d = document,
# s = d.createElement('script');
# s.async = true; s.src = 'https://cdn.vuukle.com/platform.js';
# (d.head || d.body).appendChild(s);
# })();
#   </script>
#   <div class="overlay-screen">
#   </div>
#  </body>
# </html>

# %%
#list(soup.children)

# %%
#html = list(soup.children)[2]
#html

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p>
#  The International Space Station is seen over the Earth. File photo.   | Photo Credit: <a href="https://www.thehindu.com/profile/photographers/Reuters/">Reuters</a> </p>,
#  <p>India plans to have its own space station in the future and modalities for it will be worked out after the first manned mission, Gaganyaan, scheduled to be launched by August 2022, Dr. Sivan, Chairman of Indian Space Research Organisation (ISRO) said on Friday.</p>,
#  <p>“We want to have a separate space station. We will launch a small module for microgravity experiments...,” Dr. Sivan said addressing the media. “That is our ambition,” he stated.</p>,
#  <p>The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission.</p>,
#  <p>Giving out broad contours of the planned space station, Dr. Sivan said it has been envisaged to weigh 20 tonnes and will be placed in an orbit of 400 kms above earth where astronauts can stay for 15-20 days. The time frame is 5-7 years after Gaganyaan, he stated.</p>,
#  <p>Speaking about the progress of Gaganyaan, Dr. Jitendra Singh, Minster of State for Space, said the project was on track to be realized by India’s 75th Independence Day or even earlier. “Cost approved by Union Cabinet just before the Moral Code of Conduct came in was ₹10,000 crore,” Dr. Singh said.</p>,
#  <p>A Gaganyan National Advisory Council has been created, comprising members from different institutions and industries to oversee and advise on the mission. Selection of 2-3 crew for Gaganyan will begin in six months, Dr. Singh said and added that they will undergo training for a year or year-and-a-half after that.</p>,
#  <p>The initial phase of training will be in India and the advanced stage will be done abroad, said Dr. Sivan, as the facilities did not exist to complete the project on a short timeline.</p>,
#  <p>Dr. Sivan also added that ISRO will join the international space community for a manned mission to moon in the future.</p>,
#  <p>ISRO will use its GSLV Mk-III launch vehicle, which has the necessary payload capability to launch Gaganyaan. Prior to that, two unmanned missions will be undertaken — the first one in December next year and the second, six months after that.</p>,
#  <p>Gagayaan mission aims to send a 2-3 person crew to space for a period of seven days. The spacecraft will be placed in a low earth orbit of 300-400km.</p>,
#  <p>Please enter a valid email address.</p>,
#  <p>
#  Printable version | Jun 13, 2019 5:42:17 PM | https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece
#  </p>,
#  <p class="copyright">
#  © THG PUBLISHING PVT LTD.
#  </p>,
#  <p class="author-text hidden-xs">
#  From 1980-1987, seven blast endemics have occurred in India causing severe losses
#  </p>,
#  <p class="boxTitle">Join our online subscriber community</p>,
#  <p class="boxSubTitle">Experience an advertisement-free site with article recommendations tailored for you</p>,
#  <p>Already a user? <a class="addLink" href="https://subscription.thehindu.com/signup?utm_source=adblocker&amp;utm_medium=signin&amp;utm_campaign=adblocker&amp;#signin">Sign In</a>
#  </p>,
#  <p>To know more about Ad free news reading experience and subscription <a class="addLink" href="https://subscription.thehindu.com/subscription?utm_source=adblocker&amp;utm_medium=clickhere&amp;utm_campaign=adblocker">Click Here</a></p>,
#  <p>or Please whitelist our website on your Adblocker</p>]

# %%
# as a Dictionary
cdata = {}
c  = 0
for link in soup.find_all('p'):
    cdata[c] = link
    c = c+1

# %%
#print(cdata)
for k,v in cdata.items():
    print(v)
# Out:
# <p>
# The International Space Station is seen over the Earth. File photo.   | Photo Credit: <a href="https://www.thehindu.com/profile/photographers/Reuters/">Reuters</a> </p>
# <p>India plans to have its own space station in the future and modalities for it will be worked out after the first manned mission, Gaganyaan, scheduled to be launched by August 2022, Dr. Sivan, Chairman of Indian Space Research Organisation (ISRO) said on Friday.</p>
# <p>“We want to have a separate space station. We will launch a small module for microgravity experiments...,” Dr. Sivan said addressing the media. “That is our ambition,” he stated.</p>
# <p>The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission.</p>
# <p>Giving out broad contours of the planned space station, Dr. Sivan said it has been envisaged to weigh 20 tonnes and will be placed in an orbit of 400 kms above earth where astronauts can stay for 15-20 days. The time frame is 5-7 years after Gaganyaan, he stated.</p>
# <p>Speaking about the progress of Gaganyaan, Dr. Jitendra Singh, Minster of State for Space, said the project was on track to be realized by India’s 75th Independence Day or even earlier. “Cost approved by Union Cabinet just before the Moral Code of Conduct came in was ₹10,000 crore,” Dr. Singh said.</p>
# <p>A Gaganyan National Advisory Council has been created, comprising members from different institutions and industries to oversee and advise on the mission. Selection of 2-3 crew for Gaganyan will begin in six months, Dr. Singh said and added that they will undergo training for a year or year-and-a-half after that.</p>
# <p>The initial phase of training will be in India and the advanced stage will be done abroad, said Dr. Sivan, as the facilities did not exist to complete the project on a short timeline.</p>
# <p>Dr. Sivan also added that ISRO will join the international space community for a manned mission to moon in the future.</p>
# <p>ISRO will use its GSLV Mk-III launch vehicle, which has the necessary payload capability to launch Gaganyaan. Prior to that, two unmanned missions will be undertaken — the first one in December next year and the second, six months after that.</p>
# <p>Gagayaan mission aims to send a 2-3 person crew to space for a period of seven days. The spacecraft will be placed in a low earth orbit of 300-400km.</p>
# <p>Please enter a valid email address.</p>
# <p>
# Printable version | Jun 13, 2019 5:42:17 PM | https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece
# </p>
# <p class="copyright">
# © THG PUBLISHING PVT LTD.
# </p>
# <p class="author-text hidden-xs">
# From 1980-1987, seven blast endemics have occurred in India causing severe losses
# </p>
# <p class="boxTitle">Join our online subscriber community</p>
# <p class="boxSubTitle">Experience an advertisement-free site with article recommendations tailored for you</p>
# <p>Already a user? <a class="addLink" href="https://subscription.thehindu.com/signup?utm_source=adblocker&amp;utm_medium=signin&amp;utm_campaign=adblocker&amp;#signin">Sign In</a>
# </p>
# <p>To know more about Ad free news reading experience and subscription <a class="addLink" href="https://subscription.thehindu.com/subscription?utm_source=adblocker&amp;utm_medium=clickhere&amp;utm_campaign=adblocker">Click Here</a></p>
# <p>or Please whitelist our website on your Adblocker</p>

# %%
soup.find_all('title')
# Out:
# [<title>
#  India to have a separate space station: ISRO - The Hindu
#  </title>]

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.thehindu.com/
# https://www.facebook.com/thehindu
# https://twitter.com/The_Hindu
# https://www.linkedin.com/school/the-hindu/
# https://instagram.com/the_hindu/?ref=badge
# https://www.thehindu.com/newsletter-subscription/
# https://www.thehindu.com/social/
# https://epaper.thehindu.com/?utm_source=The_Hindu_Website&utm_medium=CPC&utm_campaign=HomePageLink
# https://www.thehindu.com/
# https://www.thehindu.com/news/national/other-states/nia-team-seizes-huge-cache-of-arms-and-ammunition-in-manipur/article27899668.ece
# https://www.thehindu.com/archive/
# http://www.thehindugroup.in/subscribe/
# https://epaper.thehindu.com/?utm_source=The_Hindu_Website&utm_medium=CPC&utm_campaign=HomePageLink
# https://subscription.thehindu.com/subscription
# https://www.thehindu.com/rssfeeds/
# https://www.thehindu.com/sitemap/
# https://www.thehindu.com/
# https://tamil.thehindu.com/
# https://www.thehindubusinessline.com/
# https://bloncampus.thehindubusinessline.com/
# https://sportstar.thehindu.com/
# https://frontline.thehindu.com/
# https://www.thehinducentre.com/
# https://roofandfloor.thehindu.com/?utm_source=thehindu&utm_medium=referral&utm_campaign=Internal-Marketing
# https://step.thehindu.com/
# http://www.youngworldclub.com/
# https://www.thehindu.com/publications/
# https://www.thehindu.com/ebooks/
# https://thehinduimages.com/
# http://www.thehinduclassifieds.in/
# https://www.thehindu.com/contacts/
# #top
# https://subscription.thehindu.com/signup?utm_source=adblocker&utm_medium=signin&utm_campaign=adblocker&#signin
# https://subscription.thehindu.com/subscription?utm_source=adblocker&utm_medium=clickhere&utm_campaign=adblocker

# %%
import csv

with open('c:\\users\\hp\\downloads\\pavan2.csv', 'w', encoding="utf-16") as f:
    for key in cdata.keys():
        f.write("%s,%s\n"%(key,cdata[key]))

# %%
for link in soup.find_all("div", {"class": "clics-cont"}):
    print(link)
# Out:
# <div class="clics-cont">
# <a href="https://www.thehindu.com/entertainment/movies/how-keanu-reeves-is-conquering-the-internet/article27899390.ece"><span class="clics-text-img">
# <img alt="Keanu Reeves in John Wick" class="media-object lazy adaptive placeholder" data-device-variant="LANDSCAPE~LANDSCAPE~LANDSCAPE" data-src-template="https://th.thgim.com/entertainment/movies/fv8tbp/article27899389.ece/BINARY/thumbnail/John-Wick" data-variant="LANDSCAPE" src="https://th.thgim.com/static/img/1x1_spacer.png" title="Keanu Reeves in John Wick"/>
# </span></a>
# <a href="https://www.thehindu.com/entertainment/movies/how-keanu-reeves-is-conquering-the-internet/article27899390.ece">How Keanu Reeves is conquering the Internet </a>
# </div>
# <div class="clics-cont">
# <a href="https://www.thehindu.com/entertainment/movies/saaho-teaser-prabhas-has-something-for-die-hard-fans/article27895858.ece"><span class="clics-text-img">
# <img alt="Prabhas in Saaho" class="media-object lazy adaptive placeholder" data-device-variant="LANDSCAPE~LANDSCAPE~LANDSCAPE" data-src-template="https://th.thgim.com/entertainment/movies/k32g22/article27895857.ece/BINARY/thumbnail/Saaho-poster" data-variant="LANDSCAPE" src="https://th.thgim.com/static/img/1x1_spacer.png" title="Prabhas in Saaho"/>
# </span></a>
# <a href="https://www.thehindu.com/entertainment/movies/saaho-teaser-prabhas-has-something-for-die-hard-fans/article27895858.ece">'Saaho' teaser trailer: Prabhas has something for ‘die-hard fans’</a>
# </div>
# <div class="clics-cont">
# <a href="https://www.thehindu.com/news/national/tamil-nadu/pa-ranjith-booked-for-inciting-caste-enmity/article27823086.ece"><span class="clics-text-img">
# <img alt="Pa. Ranjith" class="media-object lazy adaptive placeholder" data-device-variant="LANDSCAPE~LANDSCAPE~LANDSCAPE" data-src-template="https://th.thgim.com/news/national/tamil-nadu/kyllrp/article25705589.ece/BINARY/thumbnail/TH10FILMDIRECTORPARANJITH" data-variant="LANDSCAPE" src="https://th.thgim.com/static/img/1x1_spacer.png" title="Pa. Ranjith"/>
# </span></a>
# <a href="https://www.thehindu.com/news/national/tamil-nadu/pa-ranjith-booked-for-inciting-caste-enmity/article27823086.ece"> Pa. Ranjith booked for inciting caste enmity</a>
# </div>
# <div class="clics-cont">
# <a href="https://www.thehindu.com/news/national/drdo-conducts-maiden-test-of-hypersonic-technology-demonstrator/article27890922.ece"><span class="clics-text-img">
# <img alt="DRDO's HSTDV model displayed at the ILA Berlin Air Show 2012" class="media-object lazy adaptive placeholder" data-device-variant="LANDSCAPE~LANDSCAPE~LANDSCAPE" data-src-template="https://th.thgim.com/incoming/x4lrmc/article27894841.ece/BINARY/thumbnail/berlin-drdo" data-variant="LANDSCAPE" src="https://th.thgim.com/static/img/1x1_spacer.png" title
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
for script in soup(["script", "style","meta"]): # remove all javascript and stylesheet code
    script.extract()
text = soup.get_text()
lines = (line.strip() for line in text.splitlines())
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
text = '\n'.join(chunk for chunk in chunks if chunk)
print(text)
# Out:
# India to have a separate space station: ISRO - The Hindu
# <
# ePaper
# Just In
# 5mins
# NIA team seizes huge cache of arms and ammunition in Manipur
# 6mins
# PM Modi meets Chinese President Xi Jinping on sidelines of SCO in Bishkek
# 21mins
# Gold remains flat; silver slides on reduced offtake
# 26mins
# Three brothers get life term in UP’s Muthber village murder case
# 27mins
# Sensex ends marginally lower in choppy trade; Yes Bank tanks 13%
# 1hr
# AIIMS resident doctors to boycott work on June 14
# 1hr
# U.K. Home Secretary Sajid Javid signs U.S. extradition order for Julian Assange
# 1hr
# India to have a separate space station: ISRO
# 1hr
# Rahul must continue as AICC chief: Siddaramaiah
# 2hrs
# Indiabulls Housing shares soar as petitioner withdraws writ petition
# 2hrs
# An-32 crash: no survivors at site, says IAF
# 2hrs
# ICC Cricket World Cup: Google’s Sundar Pichai predicts India vs England final
# 3hrs
# Return to work or face police action, Mamata tells striking junior doctors
# 3hrs
# India vs New Zealand Cricket World Cup 2019 | Live scorecard: toss delayed due to rain
# 3hrs
# Adani group gets final approval for coal mine project in Australia
# Home
# News
# National
# International
# States
# Cities
# Opinion
# Cartoon
# Columns
# Editorial
# Interview
# Lead
# Readers' Editor
# Comment
# Open Page
# Letters
# Business
# Agri-Business
# Industry
# Economy
# Markets
# Budget
# Stock Quotes
# Sport
# Cricket
# Football
# Hockey
# Tennis
# Athletics
# Motorsport
# Races
# Other Sports
# Cricket
# Crossword
# Entertainment
# Art
# Dance
# Movies
# Music
# Reviews
# Theatre
# Life & Style
# Fashion
# Fitness
# Food
# Motoring
# Travel
# Homes and gardens
# Luxury
# thREAD
# Subscribe now
# Sign in / Sign up
# India to have a separate space station: ISRO
# Share On
# Sci-Tech Science Technology Health Agriculture Environment Gadgets Internet
# ICC Cricket World Cup 2019 schedule
# Sci-Tech
# Science
# Science
# India to have a separate space station: ISRO
# Dinakar Peri
# New Delhi,
# June 13, 2019 16:29 IST
# Updated:
# June 13, 2019 17:41 IST
# Share Article
# PRINT
# A
# A
# A
# The International Space Station is seen over the Earth. File photo.   | Photo Credit: Reuters
# Dinakar Peri
# New Delhi,
# June 13, 2019 16:29 IST
# Updated:
# June 13, 2019 17:41 IST
# more-in
# The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission.
# India plans to have its own space station in the future and modalities for it will be worked out after the first manned mission, Gaganyaan, scheduled to be launched by August 2022, Dr. Sivan, Chairman of Indian Space Research Organisation (ISRO) said on Friday.“We want to have a separate space station. We will launch a small module for microgravity experiments...,” Dr. Sivan said addressing the media. “That is our ambition,” he stated.The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan m
# Frontline
# The Hindu Centre
# RoofandFloor
# STEP
# Young World Club
# Publications
# eBooks
# Images
# Classifieds
# Contact us Copyright© 2019, THG PUBLISHING PVT LTD.
# Using Ad blocker for Ad Free experience?
# Introducing The Hindu Plus
# Zero Ads
# Personalised Recommendations
# Dashboard Tool
# Briefing
# Try our "Ad free" Website
# Sign Up for 30 Days Free Trial
# Explore our Subscription Plans
# Already a user? Sign In
# To know more about Ad free news reading experience and subscription Click Here
# or Please whitelist our website on your Adblocker

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
#soup = soup.find_all('p')

print(len(soup))
print(type(soup))
# Out:
# 4
# <class 'bs4.BeautifulSoup'>

# %%
for link in soup.find_all('p'):
    print(link.text,"\n")
# Out:
# The International Space Station is seen over the Earth. File photo.   | Photo Credit: Reuters
#
# India plans to have its own space station in the future and modalities for it will be worked out after the first manned mission, Gaganyaan, scheduled to be launched by August 2022, Dr. Sivan, Chairman of Indian Space Research Organisation (ISRO) said on Friday.
#
# “We want to have a separate space station. We will launch a small module for microgravity experiments...,” Dr. Sivan said addressing the media. “That is our ambition,” he stated.
#
# The detailed project report on setting up a space station will be submitted to the government after the Gaganyaan mission.
#
# Giving out broad contours of the planned space station, Dr. Sivan said it has been envisaged to weigh 20 tonnes and will be placed in an orbit of 400 kms above earth where astronauts can stay for 15-20 days. The time frame is 5-7 years after Gaganyaan, he stated.
#
# Speaking about the progress of Gaganyaan, Dr. Jitendra Singh, Minster of State for Space, said the project was on track to be realized by India’s 75th Independence Day or even earlier. “Cost approved by Union Cabinet just before the Moral Code of Conduct came in was ₹10,000 crore,” Dr. Singh said.
#
# A Gaganyan National Advisory Council has been created, comprising members from different institutions and industries to oversee and advise on the mission. Selection of 2-3 crew for Gaganyan will begin in six months, Dr. Singh said and added that they will undergo training for a year or year-and-a-half after that.
#
# The initial phase of training will be in India and the advanced stage will be done abroad, said Dr. Sivan, as the facilities did not exist to complete the project on a short timeline.
#
# Dr. Sivan also added that ISRO will join the international space community for a manned mission to moon in the future.
#
# ISRO will use its GSLV Mk-III launch vehicle, which has the necessary payload capability to launch Gaganyaan. Prior to that, two unmanned missions will be undertaken — the first one in December next year and the second, six months after that.
#
# Gagayaan mission aims to send a 2-3 person crew to space for a period of seven days. The spacecraft will be placed in a low earth orbit of 300-400km.
#
# Please enter a valid email address.
#
#
# Printable version | Jun 13, 2019 5:42:17 PM | https://www.thehindu.com/sci-tech/science/india-to-have-a-separate-space-station-isro/article27898707.ece
#
#
#
# © THG PUBLISHING PVT LTD.
#
#
#
# From 1980-1987, seven blast endemics have occurred in India causing severe losses
#
#
# Join our online subscriber community
#
# Experience an advertisement-free site with article recommendations tailored for you
#
# Already a user? Sign In
#
#
# To know more about Ad free news reading experience and subscription Click Here
#
# or Please whitelist our website on your Adblocker

# %%
cdata2 = {}

dataList = []
for link in soup.find_all('p'):
    dataList.append(link.text)

import csv
print(len(dataList ))



import pandas as pd
from pandas import DataFrame
df = DataFrame(dataList, columns= ["Para"])
df.to_csv("c:\\users\\hp\\downloads\\Sage.csv")
# Out:
# 20
